# %%
from integration import RoseRocketIntegration,RoseRocketIntegrationBackend
from secret import secrets as pw
import requests
import xlwings as xw

# %%
orgs = pw.orgs.keys()

# %%
def getorderids():
    db=RoseRocketIntegrationBackend()
    for org in orgs:
        results=db.getOrderHistory(org)
        rr=RoseRocketIntegration(org)
        

        auth = rr.authorg(org)
        headers = {
                    'Accept': 'application/json',
                    'Authorization': 'Bearer {}'.format(auth)


                }

        apiurl = 'https://platform.roserocket.com/api/v1/orders'
        ids=[]
        for result in results:

            so = result.SALESORDERNO
            ids.append(str(so))
        params={"in_external_ids":ids}
        resp=requests.get(apiurl,json=params,headers=headers).json()
        orderids=[]

        for order in resp["orders"]:
            orderids.append(str(order["id"]))
    return orderids

# %%
def getmanifestdetails(manifestid):
    rr=RoseRocketIntegration(org)
    
    

    auth = rr.authorg(org)
    headers = {
                'Accept': 'application/json',
                'Authorization': 'Bearer {}'.format(auth)


            }
    apiurl = 'https://platform.roserocket.com/api/v1/manifests/{}'.format(manifestid)
    resp=requests.get(apiurl,headers=headers).json()
    return resp["manifest"]

# %%
ids = getorderids()
# Out:
# AUTHRESP: {'data': {'access_token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoiYTM3MDhkZDctNzhkOS00MzcxLThmODgtNTViMjYwYjcyMDBmIiwib3JnX2lkIjoiZjkxNDk5ZWItMWRjMS00N2E3LWFiZTctYTE5YzZhOThjNDRlIiwib3JnX3R5cGVfaWQiOiJjYXJyaWVyIiwidXNlcl9yb2xlIjoiYWRtaW4iLCJleHAiOjE1NjUyMTI0MzIsImlhdCI6MTU2NTEyNjAzMn0.hUN9ohR6aMH9QMFZK9nT18CNF1jqilzagqYXJeFUAso', 'refresh_token': 'ae72ad30-011b-4dc6-9c63-49b02b7bd256', 'expires_in': 86400, 'token_type': 'Bearer'}}

# %%
def getmanifestids():
    rr=RoseRocketIntegration(org)


    auth = rr.authorg(org)
    headers = {
                'Accept': 'application/json',
                'Authorization': 'Bearer {}'.format(auth)


            }
    
    ids=[]
    legs = getlegs()
    for leg in legs:
        ids.append(leg["manifest_id"])
    return ids

# %%
def getleg():
    rr=RoseRocketIntegration(org)


    auth = rr.authorg(org)
    headers = {
                'Accept': 'application/json',
                'Authorization': 'Bearer {}'.format(auth)


            }
    ids=getorderids()

    for id in ids:
        apiurl = 'https://platform.roserocket.com/api/v1/orders/{}/legs'.format(id)
        resp = requests.get(apiurl,headers=headers).json()

        legs=[]
        for leg in resp["legs"]:

            legs.append(leg)
        return legs

# %%
def main():
    data=
    {
        "stationcode":
        ,"orderno":
        ,"housebill":
        ,"ofddate":
        ,"totalcost":
        ,"totalpieces":
        ,"routingvendor":
    
    }
    pddata=[]
    legs= getlegs()
    for leg in legs:
        
    import pandas as pd
    df = pd.DataFrame([],columns=['Station Code','Order No', 'Housebill', 'OFD  Date', 'Total Cost','Total Actual Wt','Total Pieces','Routing Vendor (Primary)
'])
    
    
    wb = xw.Book()
    sheet = wb.sheets['Sheet1']
    sheet.range('A1').value =

# %%
rr=RoseRocketIntegration('130')


auth = rr.authorg('130')
headers = {
            'Accept': 'application/json',
            'Authorization': 'Bearer {}'.format(auth)


        }
ids=getorderids()

apiurl = 'https://platform.roserocket.com/api/v1/orders/{}/legs'.format('bc72ecb4-3bf7-436f-9c97-74f396e83837')
resp = requests.get(apiurl,headers=headers).json()
print(resp)
print()
apiurl = 'https://platform.roserocket.com/api/v1/manifests/{}'.format(resp["legs"][0]["manifest_id"])
resp=requests.get(apiurl,headers=headers).json()
print(resp["manifest"])
# Out:
# AUTHRESP: {'data': {'access_token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoiYTM3MDhkZDctNzhkOS00MzcxLThmODgtNTViMjYwYjcyMDBmIiwib3JnX2lkIjoiZjkxNDk5ZWItMWRjMS00N2E3LWFiZTctYTE5YzZhOThjNDRlIiwib3JnX3R5cGVfaWQiOiJjYXJyaWVyIiwidXNlcl9yb2xlIjoiYWRtaW4iLCJleHAiOjE1NjUyMzE5NzgsImlhdCI6MTU2NTE0NTU3OH0.IVJAPZtMxFkcnFjR7XwrMqRYKkOsOZ3LH1cJ69e8xCU', 'refresh_token': '6c9f0e5c-f0dd-4193-80ca-ba2cdbe03b4d', 'expires_in': 86400, 'token_type': 'Bearer'}}
# AUTHRESP: {'data': {'access_token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoiYTM3MDhkZDctNzhkOS00MzcxLThmODgtNTViMjYwYjcyMDBmIiwib3JnX2lkIjoiZjkxNDk5ZWItMWRjMS00N2E3LWFiZTctYTE5YzZhOThjNDRlIiwib3JnX3R5cGVfaWQiOiJjYXJyaWVyIiwidXNlcl9yb2xlIjoiYWRtaW4iLCJleHAiOjE1NjUyMzE5NzksImlhdCI6MTU2NTE0NTU3OX0.3xym0eMCVtYDWnGD_gYr5dZf_L9jmKuEA1Spe6qG_rY', 'refresh_token': '595568b9-19cc-4c62-a25e-613a37385187', 'expires_in': 86400, 'token_type': 'Bearer'}}
# {'legs': [{'created_at': '2019-08-06T20:00:34.65176Z', 'updated_at': '2019-08-06T20:22:49.825381Z', 'id': '10ccdb89-ec76-4d5d-94c0-a354d507b472', 'order_id': 'bc72ecb4-3bf7-436f-9c97-74f396e83837', 'sequence_id': 1, 'version': 1, 'external_id': '', 'public_id': '130-HOMEDC-47-LEG-1.1', 'org_id': 'f91499eb-1dc1-47a7-abe7-a19c6a98c44e', 'manifest_id': '2a2b930e-1265-455a-82ee-e13f10a8e005', 'origin_stop_id': '0fdac71e-f55e-4c73-b8d5-f2611404b1ef', 'destination_stop_id': '43c5355c-d9c1-423a-a0f1-1bedded1d2f3', 'type': 'delivery', 'status': 'dispatched', 'origin': {'terminal_id': 'cb75a610-3179-49e6-a926-6789ea9adc40', 'org_name': 'Greenfiber Norfolk', 'contact_name': '', 'address_1': '3421 Old Highway 8', 'address_2': '', 'suite': '', 'city': 'Norfolk', 'state': 'NE', 'country': 'US', 'postal': '68701', 'phone': '', 'phone_ext': '', 'email': '', 'fax': '', 'latitude': 41.997437, 'longitude': -97.350813}, 'destination': {'terminal_id': None, 'org_name': 'URIAH LEE', 'contact_name': '', 'address_1': '2715 PERSHING AVE.', 'address_2': '', 'suite': '', 'city': 'SHEBOYGAN', 'state': 'WI', 'country': 'US', 'postal': '53083', 'phone': '(757) 768-9402', 'phone_ext': '', 'email': '', 'fax': '', 'latitude': 43.7802102, 'longitude': -87.7417496}, 'origin_start_at': '2019-08-07T11:00:00Z', 'origin_end_at': None, 'origin_appt_start_at': None, 'origin_appt_end_at': None, 'destination_start_at': '2019-08-08T04:00:00Z', 'destination_end_at': None, 'destination_appt_start_at': None, 'destination_appt_end_at': None, 'history': {'origin_arrived_at': None, 'origin_in_at': None, 'origin_pickedup_at': None, 'origin_out_at': None, 'destination_arrived_at': None, 'destination_in_at': None, 'destination_delivered_at': None, 'destination_out_at': None}, 'pickup_notes': "OriginInstructions: ['MUST SHIP BY 08/08/19 TO BE COMPLIANT', '  VENDOR #: 6004826', '36 BAGS PER PALLET REQUIRED', 'HD PACKING SLIP MUST ACCOMPANY ORDER&#x0D;\\n', '', 'MUST CALL FOR AN APPOINTMENT @ 757-768-9402&#x0D;\\n', '   RESIDENTIAL AND LIFT GATE CHARGES PRE-APPROVED&#x0D;\\n', '', '', '']", 'delivery_notes': "OriginInstructions: ['MUST SHIP BY 08/08/19 TO BE COMPLIANT', '  VENDOR #: 6004826', '36 BAGS PER PALLET REQUIRED', 'HD PACKING SLIP MUST ACCOMPANY ORDER&#x0D;\\n', '', 'MUST CALL FOR AN APPOINTMENT @ 757-768-9402&#x0D;\\n', '   RESIDENTIAL AND LIFT GATE CHARGES PRE-APPROVED&#x0D;\\n', '', '', '']", 'accessorials': [], 'commodities': [{'id': 'eaf6efb0-4b0c-4ecf-ae8d-82418ac8a817', 'name': '30 LB COCOON2 LOOSE FILL BORAT', 'measurement_unit': 'inch', 'weight_unit': 'lb', 'freight_class': '100', 'commodity_type': 'package', 'description': '30 LB COCOON2 LOOSE FILL BORAT', 'feet': 0, 'volume': 0, 'length': 0, 'width': 0, 'height': 0, 'weight': 30, 'nmfc': '10330', 'is_stackable': False, 'quantity': 36, 'pieces': 1, 'commodity_type_other': '', 'sku': 'INS765LD'}]}]}
#
# {'id': '2a2b930e-1265-455a-82ee-e13f10a8e005', 'external_id': '', 'created_at': '2019-08-06T20:19:40.328366Z', 'updated_at': '2019-08-06T20:22:49.776677Z', 'nickname': '', 'org_id': 'f91499eb-1dc1-47a7-abe7-a19c6a98c44e', 'dispatcher_user_id': '5107f4c3-4a6a-4976-b966-a5afc82c001f', 'driver_user_id': None, 'trailer_id': None, 'partner_carrier_id': 'a7ae0979-1988-4744-ace1-74cc70231204', 'partner_carrier_service_id': '420e81b1-641a-4adf-bbb9-80244fabcb5a', 'sequential_id': 170, 'full_id': '130M0170', 'tender_id': None, 'start_at': '2019-08-07T11:00:00Z', 'status': 'assigned', 'dispatched_at': '2019-08-06T20:22:49.78245Z', 'completed_at': None}

# %%
apiurl = 'https://platform.roserocket.com/api/v1/partner_carriers/{}'.format('5f4d0417-dc56-4402-ba07-4986ce1d35aa')
resp = requests.get(apiurl,headers=headers).json()
print(resp["partner_carrier"]["name"])
# Out:
# CPU

# %%
apiurl = 'https://platform.roserocket.com/api/v1/customers/ext:{}/orders/ext:{}'.format('00LOWES','1834051')
print(apiurl)
resp = requests.get(apiurl,headers=headers)
print(resp.json()["order"]["id"])
# Out:
# https://platform.roserocket.com/api/v1/customers/ext:00LOWES/orders/ext:1834051
# 2cead14e-190d-48a9-a59b-0f432abf4272

# %%
from integration import RoseRocketIntegration, RoseRocketIntegrationBackend
from secretprod import secrets as pw
import requests
import xlwings as xw

orgs = pw.orgs.keys()


db = RoseRocketIntegrationBackend()
pddata = []
print("generating report...")
counter=0
for org in orgs:
    results = db.getOrderHistory(org)
    rr = RoseRocketIntegration(org)
    auth = rr.authorg(org)

    headers = {
        'Accept': 'application/json',
        'Authorization': 'Bearer {}'.format(auth)


    }

    
    
    for result in results:
        
       
        apiurl = 'https://platform.roserocket.com/api/v1/customers/ext:{}/orders/ext:{}'.format(
            result.ARDIVISIONNO+result.CUSTOMERNO, result.SALESORDERNO)

        data = {
            "stationcode": '', "orderno": '', "housebill": '', "ofddate": '', "totalcost": '', "totalpieces": '', "routingvendor": ''

        }
        so = result.SALESORDERNO

        # this gets the order id
        try:
            resp = requests.get(apiurl, headers=headers).json()
        except Exception as e:
            print("can't find order: {}".format(so))
            print(e)
            # continue
        # print(resp)
        if("error_code" not in resp):
            orderids = []
            data['stationcode'] = org
            data['housebill'] = so

            try:
                id = resp["order"]['id']

            except:
                print("\n \n")
                print(resp)
                print("\n \n")
            data['orderno'] = id
        else:
            continue

        apiurl = 'https://platform.roserocket.com/api/v1/orders/{}/legs'.format(
            id)
        resp = requests.get(apiurl, headers=headers).json()
        legs = []
        # legs
        
        
        for leg in resp["legs"]:
            
            if(leg["manifest_id"] != None):
                totalweight = 0
                totalpieces = 0
                data['ofddate'] = leg["history"]["destination_delivered_at"]
                # print(leg)
                manifestid = leg["manifest_id"]
                # commodities in each leg
                for comm in leg["commodities"]:
                    # print(comm["weight"])
                    # print(comm["pieces"])
                    # print(comm["quantity"])
                    totalweight += comm["weight"]
                    data['totalweight'] = totalweight
                    if(comm["pieces"] == None or comm["pieces"]>=1):
                        totalpieces += comm["quantity"]
                        data['totalpieces'] = totalpieces
                    else:
                        totalpieces += comm["pieces"]
                        data['totalpieces'] = totalpieces

                    # getting manifestid for use to get manifests
                    apiurl = 'https://platform.roserocket.com/api/v1/manifests/{}'.format(
                        manifestid)
                    resp = requests.get(apiurl, headers=headers).json()
                    # print(resp)
                    carrierid = resp["manifest"]["partner_carrier_id"]
                    # manifest is used to get partner carrier id
                    apiurl = 'https://platform.roserocket.com/api/v1/partner_carriers/{}'.format(
                        carrierid)
                    resp = requests.get(apiurl, headers=headers).json()
                    # finally with the partner carrier id you can get the parner carrier name
                    try:
                        
                        data['routingvendor'] = resp["partner_carrier"]["name"]
                    except:
                        data['routingvendor'] = "NULL"
                counter += 1
                pddata.append(data)
                print("orders processed {}".format(counter))
            else:
                pass
#                 print(
#                     "order not added to report because it hasn't shipped yet {}".format(so))
    
# print(pddata)
# Out:
# generating report...
# AUTHRESP: {'data': {'access_token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoiYTM3MDhkZDctNzhkOS00MzcxLThmODgtNTViMjYwYjcyMDBmIiwib3JnX2lkIjoiZjkxNDk5ZWItMWRjMS00N2E3LWFiZTctYTE5YzZhOThjNDRlIiwib3JnX3R5cGVfaWQiOiJjYXJyaWVyIiwidXNlcl9yb2xlIjoiYWRtaW4iLCJleHAiOjE1NjUyMzU4NDMsImlhdCI6MTU2NTE0OTQ0M30.A9HQ0_hUhPSaca3wsaphwAZthWwkhyDm5bVh0A4IZyA', 'refresh_token': '845229c4-eae6-40bf-b92b-ec0cecc2097f', 'expires_in': 86400, 'token_type': 'Bearer'}}
# orders processed 1
# orders processed 2
# orders processed 3
# orders processed 4
# orders processed 5
# orders processed 6
# orders processed 7
# orders processed 8
# orders processed 9
# orders processed 10
# orders processed 11
# orders processed 12
# orders processed 13
# orders processed 14
# orders processed 15
# orders processed 16
# orders processed 17
# orders processed 18
# orders processed 19
# orders processed 20
# orders processed 21
# orders processed 22
# orders processed 23
# orders processed 24
# orders processed 25
# orders processed 26
# orders processed 27
# orders processed 28
# orders processed 29
# orders processed 30
# orders processed 31
# orders processed 32
# orders processed 33
# orders processed 34
# orders processed 35
# orders processed 36
# orders processed 37
# orders processed 38
# orders processed 39
# orders processed 40
# orders processed 41
# orders processed 42
# orders processed 43
# orders processed 44
# orders processed 45
# orders processed 46
# orders processed 47
# orders processed 48
# orders processed 49
# orders processed 50
# orders processed 51
# orders processed 52
# orders processed 53
# orders processed 54
# orders processed 55
# orders processed 56
# orders processed 57
# orders processed 58
# orders processed 59
# orders processed 60
# orders processed 61
# orders processed 62
# orders processed 63
# orders processed 64
# orders processed 65
# orders processed 66
# orders processed 67
# orders processed 68
# orders processed 69
# orders processed 70
# orders processed 71
# orders processed 72
# orders processed 73
# orders processed 74
# orders processed 75
# orders processed 76
# orders processed 77
# orders processed 78
# orders processed 79
# orders processed 80
# orders processed 81
# orders processed 82
# orders processed 83
# orders processed 84
# orders processed 85
# orders processed 86
# orders processed 87
# orders processed 88
# orders processed 89
# orders processed 90
# orders processed 91
# orders processed 92
# orders processed 93
# orders processed 94
# orders processed 95
# orders processed 96
# orders processed 97
# orders processed 98
# AUTHRESP: {'data': {'access_token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoiYTM3MDhkZDctNzhkOS00MzcxLThmODgtNTViMjYwYjcyMDBmIiwib3JnX2lkIjoiMWE1MWRiYzMtZWMyYy00ZmQxLWIxNDAtNGJjZmQ1OWJmMTZmIiwib3JnX3R5cGVfaWQiOiJjYXJyaWVyIiwidXNlcl9yb2xlIjoiYWRtaW4iLCJleHAiOjE1NjUyMzU5NDMsImlhdCI6MTU2NTE0OTU0M30.9I3sFW2O5-FSQSsdPQyQe5raETAjaGzNFAqCu7yoEtw', 'refresh_token': 'b5041c8d-be70-465a-a681-73773bbf49f4', 'expires_in': 86400, 'token_type': 'Bearer'}}
# orders processed 99
# orders processed 100
# orders processed 101
# orders processed 102
# orders processed 103
# orders processed 104
# orders processed 105
# orders processed 106
# orders processed 107
# orders processed 108
# orders processed 109
# orders processed 110
# orders processed 111
# orders processed 112
# orders processed 113
# orders processed 114
# orders processed 115
# orders processed 116
# orders processed 117
# orders processed 118
# orders processed 119
# orders processed 120
# orders processed 121
# orders processed 122
# AUTHRESP: {'data': {'access_token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoiYTM3MDhkZDctNzhkOS00MzcxLThmODgtNTViMjYwYjcyMDBmIiwib3JnX2lkIjoiOTkzODM5NDctNDFlZi00M2Q2LThmMjEtNjIxZWVlMDE1NDJiIiwib3JnX3R5cGVfaWQiOiJjYXJyaWVyIiwidXNlcl9yb2xlIjoiYWRtaW4iLCJleHAiOjE1NjUyMzYwMDEsImlhdCI6MTU2NTE0OTYwMX0.FNJ3zVLp5HEQkQ4VJc-WJHTm9IAf91RS9OA1D9bsKOY', 'refresh_token': '018a6ff1-ef38-44b6-aa8a-7561692c17c0', 'expires_in': 86400, 'token_type': 'Bearer'}}
# orders processed 123
# orders processed 124
# orders processed 125
# orders processed 126
# orders processed 127
# orders processed 128
# orders processed 129
# orders processed 130
# orders processed 131
# orders processed 132
# orders processed 133
# orders processed 134
# orders processed 135
# orders processed 136
# orders processed 137
# orders processed 138
# orders processed 139
# orders processed 140
# orders processed 141
# orders processed 142
# orders processed 143
# orders processed 144
# orders processed 145
# orders processed 146
# orders processed 147
# orders processed 148
# orders processed 149
# orders processed 150
# orders processed 151
# orders processed 152
# orders processed 153
# orders processed 154
# orders processed 155
# orders processed 156
# orders processed 157
# orders processed 158
# orders processed 159
# orders processed 160
# orders processed 161
# orders processed 162
# orders processed 163
# AUTHRESP: {'data': {'access_token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoiYTM3MDhkZDctNzhkOS00MzcxLThmODgtNTViMjYwYjcyMDBmIiwib3JnX2lkIjoiNjliMjY2ZDctZjgwNC00MTRmLWFkYjktYjEyOGI4Yzg4ZDJmIiwib3JnX3R5cGVfaWQiOiJjYXJyaWVyIiwidXNlcl9yb2xlIjoiYWRtaW4iLCJleHAiOjE1NjUyMzYwNjIsImlhdCI6MTU2NTE0OTY2Mn0.AGgblZom6itffmHIJkOykGyhWmynen7uwe4n21TPmCo', 'refresh_token': 'ee16ab95-8492-4652-a2f6-4043ca834645', 'expires_in': 86400, 'token_type': 'Bearer'}}
# orders processed 164
# orders processed 165
# orders processed 166
# orders processed 167
# orders processed 168
# orders processed 169
# orders processed 170
# orders processed 171
# orders processed 172
# orders processed 173
# orders processed 174
# orders processed 175
# orders processed 176
# orders processed 177
# AUTHRESP: {'data': {'access_token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoiYTM3MDhkZDctNzhkOS00MzcxLThmODgtNTViMjYwYjcyMDBmIiwib3JnX2lkIjoiYTIyODE0YTQtMTY4Mi00ZWY3LTlkZDAtZWRjNGNkN2MzZDQ1Iiwib3JnX3R5cGVfaWQiOiJjYXJyaWVyIiwidXNlcl9yb2xlIjoiYWRtaW4iLCJleHAiOjE1NjUyMzYxMTMsImlhdCI6MTU2NTE0OTcxM30.95kGnLCG2VMnSwN-2pL-gwaDKz6I2jljHjS6qZjw-_E', 'refresh_token': 'dda9d79c-cd63-4766-8152-57cb7de9b0ed', 'expires_in': 86400, 'token_type': 'Bearer'}}
# orders processed 178
# orders processed 179
# orders processed 180
# orders processed 181
# orders processed 182
# orders processed 183
# orders processed 184
# orders processed 185
# orders processed 186
# orders processed 187
# orders processed 188
# orders processed 189
# orders processed 190
# orders processed 191
# orders processed 192
# orders processed 193
# orders processed 194
# orders processed 195
# orders processed 196
# orders processed 197
# orders processed 198
# orders processed 199
# orders processed 200
# orders processed 201
# orders processed 202
# orders processed 203
# orders processed 204
# orders processed 205
# orders processed 206
# orders processed 207
# orders processed 208
# orders processed 209
# orders processed 210
# orders processed 211
# orders processed 212
# orders processed 213
# orders processed 214
# AUTHRESP: {'data': {'access_token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoiYTM3MDhkZDctNzhkOS00MzcxLThmODgtNTViMjYwYjcyMDBmIiwib3JnX2lkIjoiZDg1YmVmNTQtNWQ1Yi00ODJmLTgxYmItMzViMWRkNzRlMmMwIiwib3JnX3R5cGVfaWQiOiJjYXJyaWVyIiwidXNlcl9yb2xlIjoiYWRtaW4iLCJleHAiOjE1NjUyMzYxODYsImlhdCI6MTU2NTE0OTc4Nn0.tu9LZJegV_WwE5MTe08khd66rg_irnirVuzyVT6m-80', 'refresh_token': '0031fd9f-649e-43a0-bd86-c42dd46aca13', 'expires_in': 86400, 'token_type': 'Bearer'}}
# orders processed 215
# orders processed 216
# orders processed 217
# orders processed 218
# orders processed 219
# orders processed 220
# orders processed 221
# orders processed 222
# orders processed 223
# orders processed 224
# orders processed 225
# orders processed 226
# orders processed 227
# orders processed 228
# orders processed 229
# orders processed 230
# orders processed 231
# orders processed 232
# orders processed 233
# orders processed 234
# orders processed 235
# orders processed 236
# orders processed 237
# orders processed 238
# orders processed 239
# orders processed 240
# orders processed 241
# orders processed 242
# orders processed 243
# orders processed 244
# orders processed 245
# orders processed 246
# orders processed 247
# orders processed 248
# orders processed 249
# orders processed 250
# orders processed 251
# orders processed 252
# orders processed 253
# orders processed 254
# orders processed 255
# orders processed 256
# orders processed 257
# orders processed 258
# orders processed 259
# orders processed 260
# orders processed 261
# orders processed 262
# orders processed 263
# orders processed 264
# orders processed 265
# orders processed 266
# orders processed 267
# orders processed 268
# orders processed 269
# orders processed 270
# orders processed 271
# orders processed 272
# orders processed 273
# orders processed 274
# orders processed 275
# orders processed 276
# orders processed 277
# orders processed 278
# orders processed 279
# orders processed 280
# orders processed 281
# orders processed 282
# orders processed 283
# orders processed 284
# orders processed 285
# orders processed 286
# orders processed 287
# orders processed 288
# orders processed 289
# orders processed 290
# orders processed 291
# orders processed 292
# orders processed 293
# orders processed 294
# orders processed 295
# orders processed 296
# [{'stationcode': '130', 'orderno': '71534170-daa7-4bfe-9136-dced7932645c', 'housebill': '1832961', 'ofddate': '2019-07-31T19:44:02Z', 'totalcost': '', 'totalpieces': 1, 'routingvendor': 'GREENFIBER TRUCKING', 'totalweight': 31680}, {'stationcode': '130', 'orderno': '4ae03c0b-c24c-4750-abd6-239ebc9be55c', 'housebill': '1832962', 'ofddate': '2019-08-01T16:01:13Z', 'totalcost': '', 'totalpieces': 1, 'routingvendor': 'GREENFIBER TRUCKING', 'totalweight': 31680}, {'stationcode': '130', 'orderno': 'de719968-68e2-4358-a350-e8463879e6de', 'housebill': '1833147', 'ofddate': None, 'totalcost': '', 'totalpieces': 144, 'routingvendor': 'ESTES EXPRESS', 'totalweight': 30}, {'stationcode': '130', 'orderno': '180576a9-9d69-4a5e-a4fa-67874b975408', 'housebill': '1833186', 'ofddate': '2019-07-17T20:05:41Z', 'totalcost': '', 'totalpieces': 36, 'routingvendor': 'ESTES EXPRESS', 'totalweight': 30}, {'stationcode': '130', 'orderno': 'f9828e45-a87d-4434-a90d-a25d191372db', 'housebill': '1833194', 'ofddate': None, 'totalcost': '', 'totalpieces': 36, 'routingvendor': 'ESTES EXPRESS', 'totalweight': 30}, {'stationcode': '130', 'orderno': 'b44abe4e-0a54-4a67-bed4-9406eb9bceb1', 'housebill': '1833244', 'ofddate': '2019-07-31T17:49:00Z', 'totalcost': '', 'totalpieces': 1, 'routingvendor': 'CUSTOMER PICKUP - NORFOLK', 'totalweight': 17602.2}, {'stationcode': '130', 'orderno': '3c434449-030e-4ee0-bebd-043d2b8aecdf', 'housebill': '1833293', 'ofddate': None, 'totalcost': '', 'totalpieces': 144, 'routingvendor': 'ESTES EXPRESS', 'totalweight': 30}, {'stationcode': '130', 'orderno': 'cc4e9e86-dbd7-4268-b8d0-8b73ac47e2c0', 'housebill': '1833324', 'ofddate': None, 'totalcost': '', 'totalpieces': 30, 'routingvendor': 'SWIFT', 'totalweight': 1485.9}, {'stationcode': '130', 'orderno': 'ee2df8eb-f49e-4354-8934-a37261f9a203', 'housebill': '1833325', 'ofddate': '2019-07-26T10:00:00Z', 'totalcost': '', 'totalpieces': 1, 'routingvendor': 'WESTERN EXPRESS', 'totalweight': 27432}, {'stationcode': '130', 'orderno': 'acbb3ac1-686b-421c-b6dd-a524df586519', 'housebill': '1833354', 'ofddate': '2019-07-18T20:31:46Z', 'totalcost': '', 'totalpieces': 36, 'routingvendor': 'ESTES EXPRESS', 'totalweight': 30}, {'stationcode': '130', 'orderno': 'b2bed1a0-6904-4bf4-b662-d3c9302125e4', 'housebill': '1833369', 'ofddate': '2019-07-23T18:23:02Z', 'totalcost': '', 'totalpieces': 1, 'routingvendor': 'GREENFIBER TRUCKING', 'totalweight': 34560}, {'stationcode': '130', 'orderno': 'c7dfb5d2-f8e7-4a95-ab54-aaab0d12d29e', 'housebill': '1833376', 'ofddate': None, 'totalcost': '', 'totalpieces': 30, 'routingvendor': 'SCHNEIDER NATIONAL INC.', 'totalweight': 800.1}, {'stationcode': '130', 'orderno': '5fbbc06f-9a20-4228-a88a-142b41afe872', 'housebill': '1833377', 'ofddate': None, 'totalcost': '', 'totalpieces': 30, 'routingvendor': 'SCHNEIDER NATIONAL INC.', 'totalweight': 800.1}, {'stationcode': '130', 'orderno': 'ca6cea73-e636-4231-bbad-466ed2fd7653', 'housebill': '1833410', 'ofddate': '2019-07-30T17:05:20Z', 'totalcost': '', 'totalpieces': 216, 'routingvendor': 'ESTES EXPRESS', 'totalweight': 30}, {'stationcode': '130', 'orderno': '24166a42-19f8-4689-9b59-9996bf39810a', 'housebill': '1833434', 'ofddate': '2019-07-29T16:59:10Z', 'totalcost': '', 'totalpieces': 1, 'routingvendor': 'GREENFIBER TRUCKING', 'totalweight': 31680}, {'stationcode': '130', 'orderno': '47aac08a-67f3-4479-bd35-50cb9d2bb3ef', 'housebill': '1833435', 'ofddate': '2019-07-30T19:45:53Z', 'totalcost': '', 'totalpieces': 1, 'routingvendor': 'GREENFIBER TRUCKING', 'totalweight': 36960}, {'stationcode': '130', 'orderno': '0553fccf-5fee-4828-8294-5551c813c2b7', 'housebill': '1833436', 'ofddate': '2019-07-23T18:15:51Z', 'totalcost': '', 'totalpieces': 1, 'routingvendor': 'HOWLEY TRUCKING', 'totalweight': 36960}, {'stationcode': '130', 'orderno': '711a209a-87d7-4144-b0b7-dee33277b4eb', 'housebill': '1833437', 'ofddate': '2019-07-29T21:03:01Z', 'totalcost': '', 'totalpieces': 1, 'routingvendor': 'WATCO SUPPLY CHAIN', 'totalweight': 31680 ...

# %%
import pandas as pd
df = pd.DataFrame(pddata)

path=r"Y:/shipmentreport.xlsx"
wb = xw.Book()
sheet = wb.sheets['Sheet1']
sheet.range('A1').value = df

# %%
df = pd.DataFrame(pddata)
df.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-9b31f94cb3b8> in <module>
# ----> 1 df = pd.DataFrame(pddata,index=False)
#       2 df.head()
#
# c:\users\friesdj\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     446
#     447                     mgr = arrays_to_mgr(arrays, columns, index, columns,
# --> 448                                         dtype=dtype)
#     449                 else:
#     450                     mgr = init_ndarray(data, index, columns, dtype=dtype,
#
# c:\users\friesdj\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#      51         index = extract_index(arrays)
#      52     else:
# ---> 53         index = ensure_index(index)
#      54
#      55     # don't force copy because getting jammed in an ndarray anyway
#
# c:\users\friesdj\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\indexes\base.py in ensure_index(index_like, copy)
#    5376             index_like = copy(index_like)
#    5377
# -> 5378     return Index(index_like)
#    5379
#    5380
#
# c:\users\friesdj\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\indexes\base.py in __new__(cls, data, dtype, copy, name, fastpath, tupleize_cols, **kwargs)
#     466                          **kwargs)
#     467         elif data is None or is_scalar(data):
# --> 468             cls._scalar_data_error(data)
#     469         else:
#     470             if tupleize_cols and is_list_like(data):
#
# c:\users\friesdj\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\indexes\base.py in _scalar_data_error(cls, data)
#    3797         raise TypeError('{0}(...) must be called with a collection of some '
#    3798                         'kind, {1} was passed'.format(cls.__name__,
# -> 3799                                                       repr(data)))
#    3800
#    3801     @classmethod
#
# TypeError: Index(...) must be called with a collection of some kind, False was passed
