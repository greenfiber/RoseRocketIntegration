# %%
from integration import RoseRocketIntegration,RoseRocketIntegrationBackend
from secretprod import secrets as pw
import requests
import xlwings as xw
import pprint
pp = pprint.PrettyPrinter()

# %%
orgs = pw.orgs.keys()

# %%
def getorderids():
    db=RoseRocketIntegrationBackend()
    for org in orgs:
        results=db.getOrderHistory(org)
        rr=RoseRocketIntegration(org)
        

        auth = rr.authorg(org)
        headers = {
                    'Accept': 'application/json',
                    'Authorization': 'Bearer {}'.format(auth)


                }

        apiurl = 'https://platform.roserocket.com/api/v1/orders'
        ids=[]
        for result in results:

            so = result.SALESORDERNO
            ids.append(str(so))
        params={"in_external_ids":ids}
        resp=requests.get(apiurl,json=params,headers=headers).json()
        orderids=[]

        for order in resp["orders"]:
            orderids.append(str(order["id"]))
    return orderids

# %%
def getmanifestdetails(manifestid):
    rr=RoseRocketIntegration(org)
    
    

    auth = rr.authorg(org)
    headers = {
                'Accept': 'application/json',
                'Authorization': 'Bearer {}'.format(auth)


            }
    apiurl = 'https://platform.roserocket.com/api/v1/manifests/{}'.format(manifestid)
    resp=requests.get(apiurl,headers=headers).json()
    return resp["manifest"]

# %%
ids = getorderids()
# Out:
# AUTHRESP: {'data': {'access_token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoiYTM3MDhkZDctNzhkOS00MzcxLThmODgtNTViMjYwYjcyMDBmIiwib3JnX2lkIjoiZjkxNDk5ZWItMWRjMS00N2E3LWFiZTctYTE5YzZhOThjNDRlIiwib3JnX3R5cGVfaWQiOiJjYXJyaWVyIiwidXNlcl9yb2xlIjoiYWRtaW4iLCJleHAiOjE1NjUyMTI0MzIsImlhdCI6MTU2NTEyNjAzMn0.hUN9ohR6aMH9QMFZK9nT18CNF1jqilzagqYXJeFUAso', 'refresh_token': 'ae72ad30-011b-4dc6-9c63-49b02b7bd256', 'expires_in': 86400, 'token_type': 'Bearer'}}

# %%
def getmanifestids():
    rr=RoseRocketIntegration(org)


    auth = rr.authorg(org)
    headers = {
                'Accept': 'application/json',
                'Authorization': 'Bearer {}'.format(auth)


            }
    
    ids=[]
    legs = getlegs()
    for leg in legs:
        ids.append(leg["manifest_id"])
    return ids

# %%
def getleg():
    rr=RoseRocketIntegration(org)


    auth = rr.authorg(org)
    headers = {
                'Accept': 'application/json',
                'Authorization': 'Bearer {}'.format(auth)


            }
    ids=getorderids()

    for id in ids:
        apiurl = 'https://platform.roserocket.com/api/v1/orders/{}/legs'.format(id)
        resp = requests.get(apiurl,headers=headers).json()

        legs=[]
        for leg in resp["legs"]:

            legs.append(leg)
        return legs

# %%
def main():
    data=
    {
        "stationcode":
        ,"orderno":
        ,"housebill":
        ,"ofddate":
        ,"totalcost":
        ,"totalpieces":
        ,"routingvendor":
    
    }
    pddata=[]
    legs= getlegs()
    for leg in legs:
        
    import pandas as pd
    df = pd.DataFrame([],columns=['Station Code','Order No', 'Housebill', 'OFD  Date', 'Total Cost','Total Actual Wt','Total Pieces','Routing Vendor (Primary)
'])
    
    
    wb = xw.Book()
    sheet = wb.sheets['Sheet1']
    sheet.range('A1').value =

# %%
rr=RoseRocketIntegration('906')


auth = rr.authorg('906')
headers = {
            'Accept': 'application/json',
            'Authorization': 'Bearer {}'.format(auth)


        }
# ids=getorderids()

# apiurl = 'https://platform.roserocket.com/api/v1/orders/{}/legs'.format('bc72ecb4-3bf7-436f-9c97-74f396e83837')
# resp = requests.get(apiurl,headers=headers).json()
# pp.pprint(resp)# print()
apiurl = 'https://platform.roserocket.com/api/v1/manifests/{}/legs'.format('0d5ccfee-94be-4e66-b7f4-acef07518038')
resp=requests.get(apiurl,headers=headers).json()
# pp.pprint(resp)
id='3984974a-6530-4f32-94f8-73af0b2a8d57'
for leg in resp['legs']:
    if(len(resp['legs']) > 1):
        if(id == leg['order_id']):
            print("Duplicate order {} on manifest {} cost removed!".format(id,'0d5ccfee-94be-4e66-b7f4-acef07518038'))
#             print(resp["manifest_payment"]["sub_total_amount"])
        else:
            print("Keeping cost on order {}".format(leg["order_id"]))
    else:

            data['totalcost'] = resp["manifest_payment"]["sub_total_amount"]
# Out:
# AUTHRESP: {'data': {'access_token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoiYTM3MDhkZDctNzhkOS00MzcxLThmODgtNTViMjYwYjcyMDBmIiwib3JnX2lkIjoiZDg1YmVmNTQtNWQ1Yi00ODJmLTgxYmItMzViMWRkNzRlMmMwIiwib3JnX3R5cGVfaWQiOiJjYXJyaWVyIiwidXNlcl9yb2xlIjoiYWRtaW4iLCJleHAiOjE1NjkzMzQ3MzMsImlhdCI6MTU2OTI0ODMzM30.UuBopx6drUY-abZEsFOvlwiicgeFczR7zKLjQCmd2A0', 'refresh_token': 'bae7705d-d20a-4750-ac32-c5fd15247665', 'expires_in': 86400, 'token_type': 'Bearer'}}
# Duplicate order 3984974a-6530-4f32-94f8-73af0b2a8d57 on manifest 0d5ccfee-94be-4e66-b7f4-acef07518038 cost removed!
# Keeping cost on order 0b2fa41b-4721-4a81-85c9-fc79826744c6

# %%
from integration import RoseRocketIntegration, RoseRocketIntegrationBackend
from secretprod import secrets as pw
import requests
import xlwings as xw
import pprint
orgs = pw.orgs.keys()


db = RoseRocketIntegrationBackend()
pddata = []
print("generating report...")
counter=0
for org in orgs:
    results = db.getOrderHistory(org)
    rr = RoseRocketIntegration(org)
    auth = rr.authorg(org)

    headers = {
        'Accept': 'application/json',
        'Authorization': 'Bearer {}'.format(auth)


    }
    apiurl='https://platform.roserocket.com/api/v1/bills'
    bills=requests.get(apiurl,headers=headers).json()
    
    
    for result in results:
        
       
        apiurl = 'https://platform.roserocket.com/api/v1/customers/ext:{}/orders/ext:{}'.format(
            result.ARDIVISIONNO+result.CUSTOMERNO, result.SALESORDERNO)

        data = {
            "stationcode": '', "orderno": '', "housebill": '', "ofddate": '', "totalcost": '', "totalpieces": '', "routingvendor": ''

        }
        so = result.SALESORDERNO

        # this gets the order id
        try:
            resp = requests.get(apiurl, headers=headers).json()
        except Exception as e:
            print("can't find order: {}".format(so))
            print(e)
            # continue
        # print(resp)
        if("error_code" not in resp):
            orderids = []
            data['stationcode'] = org
            data['housebill'] = so

            try:
                id = resp["order"]['id']

            except:
                print("\n \n")
                print(resp)
                print("\n \n")
            data['orderno'] = id
        else:
            continue

        apiurl = 'https://platform.roserocket.com/api/v1/orders/{}/legs'.format(
            id)
        resp = requests.get(apiurl, headers=headers).json()
        legs = []
        # legs
        
        
        for leg in resp["legs"]:
            
            if(leg["manifest_id"] != None):
                totalweight = 0
                totalpieces = 0
                data['ofddate'] = leg["history"]["destination_delivered_at"]
                # print(leg)
                manifestid = leg["manifest_id"]
                # commodities in each leg
                for comm in leg["commodities"]:
                    # print(comm["weight"])
                    # print(comm["pieces"])
                    # print(comm["quantity"])
                    
                    if(comm["quantity"] == 1):
                        totalpieces += comm["pieces"]
                        data['totalpieces'] = totalpieces
                        totalweight = comm["weight"]
                        data['totalweight'] = totalweight
                    elif(comm["pieces"]==1):
                        totalpieces += comm["quantity"]
                        data['totalpieces'] = totalpieces
                        totalweight = comm["weight"]*totalpieces
                        data['totalweight'] = totalweight

                    # getting manifestid for use to get manifests
                apiurl = 'https://platform.roserocket.com/api/v1/manifests/{}/payment'.format(
                    manifestid)
                resp = requests.get(apiurl, headers=headers).json()
                data['totalcost']=resp["manifest_payment"]["sub_total_amount"]
                #get partner carrierid
                apiurl = 'https://platform.roserocket.com/api/v1/manifests/{}/'.format(
                    manifestid)
                resp = requests.get(apiurl, headers=headers).json()
                
                carrierid = resp["manifest"]["partner_carrier_id"]
                # manifest is used to get partner carrier id
                apiurl = 'https://platform.roserocket.com/api/v1/partner_carriers/{}'.format(
                    carrierid)
                resp = requests.get(apiurl, headers=headers).json()
                # finally with the partner carrier id you can get the parner carrier name
                try:

                    data['routingvendor'] = resp["partner_carrier"]["name"]
                except:
                    data['routingvendor'] = "NULL"
            
            
                
                counter += 1
                pddata.append(data)
                print("orders processed {}".format(counter))
            else:
                pass
#                 print(
#                     "order not added to report because it hasn't shipped yet {}".format(so))
    
# print(pddata)
# Out:
# generating report...
# AUTHRESP: {'data': {'access_token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoiYTM3MDhkZDctNzhkOS00MzcxLThmODgtNTViMjYwYjcyMDBmIiwib3JnX2lkIjoiZjkxNDk5ZWItMWRjMS00N2E3LWFiZTctYTE5YzZhOThjNDRlIiwib3JnX3R5cGVfaWQiOiJjYXJyaWVyIiwidXNlcl9yb2xlIjoiYWRtaW4iLCJleHAiOjE1NjU4MDE0OTAsImlhdCI6MTU2NTcxNTA5MH0.Uh9jgWZABo_Gt0Uu_urrmsn-vmxwrG3REE6aT76C79o', 'refresh_token': 'f7591892-0e1d-4951-94a4-f750fd41ff6c', 'expires_in': 86400, 'token_type': 'Bearer'}}
# orders processed 1
# orders processed 2
# orders processed 3
# orders processed 4
# orders processed 5
# orders processed 6
# orders processed 7
# orders processed 8
# orders processed 9
# orders processed 10
# orders processed 11
# orders processed 12
# orders processed 13
# orders processed 14
# orders processed 15
# orders processed 16
# orders processed 17
# orders processed 18
# orders processed 19
# orders processed 20
# orders processed 21
# orders processed 22
# orders processed 23
# orders processed 24
# orders processed 25
# orders processed 26
# orders processed 27
# orders processed 28
# AUTHRESP: {'data': {'access_token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoiYTM3MDhkZDctNzhkOS00MzcxLThmODgtNTViMjYwYjcyMDBmIiwib3JnX2lkIjoiMWE1MWRiYzMtZWMyYy00ZmQxLWIxNDAtNGJjZmQ1OWJmMTZmIiwib3JnX3R5cGVfaWQiOiJjYXJyaWVyIiwidXNlcl9yb2xlIjoiYWRtaW4iLCJleHAiOjE1NjU4MDE1MjYsImlhdCI6MTU2NTcxNTEyNn0.5F-ykytEitpZre-70RaZhFk10ZBGa8u_gfUFTqN6-bc', 'refresh_token': '55aab503-b65b-4426-9e9b-9871bdcd4bc9', 'expires_in': 86400, 'token_type': 'Bearer'}}
# orders processed 29
# orders processed 30
# orders processed 31
# orders processed 32
# orders processed 33
# orders processed 34
# orders processed 35
# orders processed 36
# orders processed 37
# orders processed 38
# orders processed 39
# orders processed 40
# orders processed 41
# orders processed 42
# orders processed 43
# orders processed 44
# orders processed 45
# orders processed 46
# orders processed 47
# orders processed 48
# orders processed 49
# orders processed 50
# orders processed 51
# orders processed 52
# orders processed 53
# orders processed 54
# orders processed 55
# orders processed 56
# orders processed 57
# orders processed 58
# orders processed 59
# orders processed 60
# orders processed 61
# orders processed 62
# orders processed 63
# orders processed 64
# orders processed 65
# orders processed 66
# orders processed 67
# orders processed 68
# orders processed 69
# orders processed 70
# AUTHRESP: {'data': {'access_token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoiYTM3MDhkZDctNzhkOS00MzcxLThmODgtNTViMjYwYjcyMDBmIiwib3JnX2lkIjoiOTkzODM5NDctNDFlZi00M2Q2LThmMjEtNjIxZWVlMDE1NDJiIiwib3JnX3R5cGVfaWQiOiJjYXJyaWVyIiwidXNlcl9yb2xlIjoiYWRtaW4iLCJleHAiOjE1NjU4MDE1NzEsImlhdCI6MTU2NTcxNTE3MX0.HmyRUPfQQ0maLbwUlG68Caq6_RMJQcnRivKJSoGHHRo', 'refresh_token': '6d38d240-dbb3-41b8-be03-dd6dde581c1c', 'expires_in': 86400, 'token_type': 'Bearer'}}
# orders processed 71
# orders processed 72
# orders processed 73
# orders processed 74
# orders processed 75
# orders processed 76
# orders processed 77
# orders processed 78
# orders processed 79
# orders processed 80
# orders processed 81
# orders processed 82
# orders processed 83
# orders processed 84
# orders processed 85
# orders processed 86
# orders processed 87
# orders processed 88
# orders processed 89
# orders processed 90
# orders processed 91
# orders processed 92
# orders processed 93
# orders processed 94
# orders processed 95
# orders processed 96
# orders processed 97
# orders processed 98
# orders processed 99
# orders processed 100
# orders processed 101
# AUTHRESP: {'data': {'access_token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoiYTM3MDhkZDctNzhkOS00MzcxLThmODgtNTViMjYwYjcyMDBmIiwib3JnX2lkIjoiNjliMjY2ZDctZjgwNC00MTRmLWFkYjktYjEyOGI4Yzg4ZDJmIiwib3JnX3R5cGVfaWQiOiJjYXJyaWVyIiwidXNlcl9yb2xlIjoiYWRtaW4iLCJleHAiOjE1NjU4MDE2MDMsImlhdCI6MTU2NTcxNTIwM30.zlTByQpJ_oGqe_dhmOYBeEnm2uRxpKPcGoTr1ugE5O8', 'refresh_token': 'bf844bc6-75e1-4e55-a397-647be2bc3e33', 'expires_in': 86400, 'token_type': 'Bearer'}}
# orders processed 102
# orders processed 103
# orders processed 104
# orders processed 105
# orders processed 106
# orders processed 107
# orders processed 108
# orders processed 109
# orders processed 110
# orders processed 111
# orders processed 112
# AUTHRESP: {'data': {'access_token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoiYTM3MDhkZDctNzhkOS00MzcxLThmODgtNTViMjYwYjcyMDBmIiwib3JnX2lkIjoiYTIyODE0YTQtMTY4Mi00ZWY3LTlkZDAtZWRjNGNkN2MzZDQ1Iiwib3JnX3R5cGVfaWQiOiJjYXJyaWVyIiwidXNlcl9yb2xlIjoiYWRtaW4iLCJleHAiOjE1NjU4MDE2MTcsImlhdCI6MTU2NTcxNTIxN30.0yg_KyOxdT5aP2Q4A-8hsb03H6109E4QloAE9F6hj2c', 'refresh_token': 'f911dc71-39ae-45e1-b22b-627898d60e35', 'expires_in': 86400, 'token_type': 'Bearer'}}
# orders processed 113
# orders processed 114
# orders processed 115
# orders processed 116
# orders processed 117
# orders processed 118
# orders processed 119
# orders processed 120
# orders processed 121
# orders processed 122
# orders processed 123
# orders processed 124
# orders processed 125
# orders processed 126
# orders processed 127
# orders processed 128
# orders processed 129
# orders processed 130
# orders processed 131
# orders processed 132
# orders processed 133
# orders processed 134
# orders processed 135
# orders processed 136
# orders processed 137
# orders processed 138
# AUTHRESP: {'data': {'access_token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoiYTM3MDhkZDctNzhkOS00MzcxLThmODgtNTViMjYwYjcyMDBmIiwib3JnX2lkIjoiZDg1YmVmNTQtNWQ1Yi00ODJmLTgxYmItMzViMWRkNzRlMmMwIiwib3JnX3R5cGVfaWQiOiJjYXJyaWVyIiwidXNlcl9yb2xlIjoiYWRtaW4iLCJleHAiOjE1NjU4MDE2NDksImlhdCI6MTU2NTcxNTI0OX0.O20m7clN_PAlsxZKLQlgPJfPUTfXMtQr-dHXREeRBVU', 'refresh_token': '73566d63-86cf-42bd-9015-6b686a1d19b1', 'expires_in': 86400, 'token_type': 'Bearer'}}
# orders processed 139
# orders processed 140
# orders processed 141
# orders processed 142
# orders processed 143
# orders processed 144
# orders processed 145
# orders processed 146
# orders processed 147
# orders processed 148
# orders processed 149
# orders processed 150
# orders processed 151
# orders processed 152
# orders processed 153
# orders processed 154
# orders processed 155
# orders processed 156
# orders processed 157
# orders processed 158
# orders processed 159
# orders processed 160
# orders processed 161
# orders processed 162
# orders processed 163
# orders processed 164
# orders processed 165
# orders processed 166
# orders processed 167
# orders processed 168
# orders processed 169
# orders processed 170
# orders processed 171
# orders processed 172
# orders processed 173
# orders processed 174
# orders processed 175
# orders processed 176
# orders processed 177
# orders processed 178
# orders processed 179
# orders processed 180
# orders processed 181
# orders processed 182
# orders processed 183
# orders processed 184
# orders processed 185
# orders processed 186
# orders processed 187
# orders processed 188
# orders processed 189
# orders processed 190
# orders processed 191
# orders processed 192
# orders processed 193
# orders processed 194
# orders processed 195
# orders processed 196
# orders processed 197
# orders processed 198
# orders processed 199
# orders processed 200
# orders processed 201
# orders processed 202
# orders processed 203
# orders processed 204
# orders processed 205
# orders processed 206
# orders processed 207
# orders processed 208

# %%
import pandas as pd
df = pd.DataFrame(pddata)

path=r"Y:/shipmentreport.xlsx"
wb = xw.Book()
sheet = wb.sheets['Sheet1']
sheet.range('A1').value = df

# %%
apiurl='https://platform.roserocket.com/api/v1/bills'
for org in orgs:
    auth = rr.authorg(org)
    headers = {
            'Accept': 'application/json',
            'Authorization': 'Bearer {}'.format(auth)


        }
    resp=requests.get(apiurl,headers=headers)
    # print(resp.json())
    import pprint
    pp = pprint.PrettyPrinter()
    pp.pprint(resp.json())
#     print(resp.json()['bills'][0]['partner_carrier_id'])
# Out:
# AUTHRESP: {'data': {'access_token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoiYTM3MDhkZDctNzhkOS00MzcxLThmODgtNTViMjYwYjcyMDBmIiwib3JnX2lkIjoiZjkxNDk5ZWItMWRjMS00N2E3LWFiZTctYTE5YzZhOThjNDRlIiwib3JnX3R5cGVfaWQiOiJjYXJyaWVyIiwidXNlcl9yb2xlIjoiYWRtaW4iLCJleHAiOjE1NjUyOTAxMjMsImlhdCI6MTU2NTIwMzcyM30.b5DVJlWNF4EhiNkWuhc1pnZq5qI51lgt3MtRWDvw4IQ', 'refresh_token': '9669ff73-47bd-4b29-9863-dd1c4df74256', 'expires_in': 86400, 'token_type': 'Bearer'}}
# {'bills': [{'bill_date': '2019-08-06',
#             'bill_to': {'address_1': '',
#                         'address_2': '',
#                         'city': '',
#                         'company_name': 'SIGNOR TRUCKING, INC.',
#                         'contact_name': 'SIGNOR TRUCKING, INC.',
#                         'country': '',
#                         'postal': '',
#                         'state': ''},
#             'cc_to_email': '',
#             'created_by': '5107f4c3-4a6a-4976-b966-a5afc82c001f',
#             'currency_id': 'usd',
#             'driver_id': None,
#             'due_date': '2019-09-05',
#             'external_id': '',
#             'full_id': 'BILL-130M0121',
#             'id': '9e1ec77f-00a0-49a8-89c6-59397b6a3765',
#             'is_tax_on': False,
#             'master_trip_id': 'e9a81638-9df3-4eea-9d28-65f04779385d',
#             'notes': '',
#             'org_id': 'f91499eb-1dc1-47a7-abe7-a19c6a98c44e',
#             'paid_at': None,
#             'partner_carrier_id': 'dd09a18f-6ff5-4ef2-b992-16f2f21eaa28',
#             'pay_term_id': '76db5afb-b848-418b-be4b-0f099104f74b',
#             'qb_error_msg': '',
#             'qb_exported_at': None,
#             'qb_external_id': '',
#             'reference_number': 'BILL-130M0121',
#             'remit_to': {'address_1': '',
#                          'address_2': '',
#                          'city': '',
#                          'company_name': 'Greenfiber Norfolk',
#                          'contact_name': 'WENDY CARLSON',
#                          'country': '',
#                          'postal': '',
#                          'state': ''},
#             'revision': 1,
#             'send_to_email': '',
#             'sent_at': None,
#             'status_id': 'saved',
#             'sub_total_amount': 1850,
#             'tax_amount': 0,
#             'total_amount': 1850}],
#  'limit': 20,
#  'offset': 0,
#  'total': 1}
# AUTHRESP: {'data': {'access_token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoiYTM3MDhkZDctNzhkOS00MzcxLThmODgtNTViMjYwYjcyMDBmIiwib3JnX2lkIjoiMWE1MWRiYzMtZWMyYy00ZmQxLWIxNDAtNGJjZmQ1OWJmMTZmIiwib3JnX3R5cGVfaWQiOiJjYXJyaWVyIiwidXNlcl9yb2xlIjoiYWRtaW4iLCJleHAiOjE1NjUyOTAxMjQsImlhdCI6MTU2NTIwMzcyNH0.40yKgn8_ZEQrKIDtT9-JeuxSatVApeGm3mM9uPyWxZM', 'refresh_token': 'fc7ef599-71b2-4083-a64c-922d52cf718e', 'expires_in': 86400, 'token_type': 'Bearer'}}
# {'bills': [], 'limit': 20, 'offset': 0, 'total': 0}
# AUTHRESP: {'data': {'access_token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoiYTM3MDhkZDctNzhkOS00MzcxLThmODgtNTViMjYwYjcyMDBmIiwib3JnX2lkIjoiOTkzODM5NDctNDFlZi00M2Q2LThmMjEtNjIxZWVlMDE1NDJiIiwib3JnX3R5cGVfaWQiOiJjYXJyaWVyIiwidXNlcl9yb2xlIjoiYWRtaW4iLCJleHAiOjE1NjUyOTAxMjQsImlhdCI6MTU2NTIwMzcyNH0.PidOyL19JOaScgdJLURvYKAIThTjFEFivR8y9T0wATo', 'refresh_token': '3d5c822e-7d5b-436d-a634-25d3ee6e8bd0', 'expires_in': 86400, 'token_type': 'Bearer'}}
# {'bills': [], 'limit': 20, 'offset': 0, 'total': 0}
# AUTHRESP: {'data': {'access_token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoiYTM3MDhkZDctNzhkOS00MzcxLThmODgtNTViMjYwYjcyMDBmIiwib3JnX2lkIjoiNjliMjY2ZDctZjgwNC00MTRmLWFkYjktYjEyOGI4Yzg4ZDJmIiwib3JnX3R5cGVfaWQiOiJjYXJyaWVyIiwidXNlcl9yb2xlIjoiYWRtaW4iLCJleHAiOjE1NjUyOTAxMjUsImlhdCI6MTU2NTIwMzcyNX0.IYeSDz0dz3y2wMVJ5rLSwPksS-qMDTtTksfT7qAhtes', 'refresh_token': 'a9687465-8a4a-42cf-8236-a14b5a649a10', 'expires_in': 86400, 'token_type': 'Bearer'}}
# {'bills': [], 'limit': 20, 'offset': 0, 'total': 0}
# AUTHRESP: {'data': {'access_token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoiYTM3MDhkZDctNzhkOS00MzcxLThmODgtNTViMjYwYjcyMDBmIiwib3JnX2lkIjoiYTIyODE0YTQtMTY4Mi00ZWY3LTlkZDAtZWRjNGNkN2MzZDQ1Iiwib3JnX3R5cGVfaWQiOiJjYXJyaWVyIiwidXNlcl9yb2xlIjoiYWRtaW4iLCJleHAiOjE1NjUyOTAxMjUsImlhdCI6MTU2NTIwMzcyNX0.wi5_vzDagE_2KPPz6O_0p7r8Gxtev1uylQ_zjc9-7CQ', 'refresh_token': 'c852637f-2e57-4770-8a5e-04fa093b8712', 'expires_in': 86400, 'token_type': 'Bearer'}}
# {'bills': [], 'limit': 20, 'offset': 0, 'total': 0}
# AUTHRESP: {'data': {'access_token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoiYTM3MDhkZDctNzhkOS00MzcxLThmODgtNTViMjYwYjcyMDBmIiwib3JnX2lkIjoiZDg1YmVmNTQtNWQ1Yi00ODJmLTgxYmItMzViMWRkNzRlMmMwIiwib3JnX3R5cGVfaWQiOiJjYXJyaWVyIiwidXNlcl9yb2xlIjoiYWRtaW4iLCJleHAiOjE1NjUyOTAxMjYsImlhdCI6MTU2NTIwMzcyNn0.cZ9Tfql0nbUoACkcJrMSTVlBYtW-nTyzNs7537MLTsY', 'refresh_token': '8f543ff8-9597-47a0-8f37-0d06d7d0bcc8', 'expires_in': 86400, 'token_type': 'Bearer'}}
# {'bills': [{'bill_date': '2019-08-06',
#             'bill_to': {'address_1': '',
#                         'address_2': '',
#                         'city': '',
#                         'company_name': 'DUPRE LOGISTICS, LLC',
#                         'contact_name': 'DUPRE LOGISTICS, LLC',
#                         'country': '',
#                         'postal': '',
#                         'state': ''},
#             'cc_to_email': '',
#             'created_by': '014a9f9b-1772-461d-a54b-61788189f428',
#             'currency_id': 'usd',
#             'driver_id': None,
#             'due_date': '2019-09-05',
#             'external_id': '',
#             'full_id': 'BILL-906M0010',
#             'id': 'b36b1dc5-64bf-42a6-b8b5-2dbb7ded642a',
#             'is_tax_on': False,
#             'master_trip_id': 'd1fccdd0-edee-4e73-86fb-41bc72a594a4',
#             'notes': '',
#             'org_id': 'd85bef54-5d5b-482f-81bb-35b1dd74e2c0',
#             'paid_at': None,
#             'partner_carrier_id': '90461068-737d-4a93-b71a-518aa55b8337',
#             'pay_term_id': 'a4704168-e929-4c89-b5d9-88776fadd3ab',
#             'qb_error_msg': '',
#             'qb_exported_at': None,
#             'qb_external_id': '',
#             'reference_number': 'BILL-906M0010',
#             'remit_to': {'address_1': '',
#                          'address_2': '',
#                          'city': '',
#                          'company_name': 'Greenfiber Wilkes-Barre',
#                          'contact_name': 'Teresa Eyler',
#                          'country': '',
#                          'postal': '',
#                          'state': ''},
#             'revision': 1,
#             'send_to_email': '',
#             'sent_at': None,
#             'status_id': 'saved',
#             'sub_total_amount': 1150,
#             'tax_amount': 0,
#             'total_amount': 1150},
#            {'bill_date': '2019-08-05',
#             'bill_to': {'address_1': '',
#                         'address_2': '',
#                         'city': '',
#                         'company_name': 'JEH',
#                         'contact_name': 'JEH',
#                         'country': '',
#                         'postal': '',
#                         'state': ''},
#             'cc_to_email': '',
#             'created_by': '014a9f9b-1772-461d-a54b-61788189f428',
#             'currency_id': 'usd',
#             'driver_id': None,
#             'due_date': '2019-09-04',
#             'external_id': '',
#             'full_id': 'BILL-906M0054',
#             'id': 'd43b5feb-5759-4e75-8071-c0acc1c53e70',
#             'is_tax_on': False,
#             'master_trip_id': 'c0583a3c-d66f-49c6-8635-7f454ef47695',
#             'notes': '',
#             'org_id': 'd85bef54-5d5b-482f-81bb-35b1dd74e2c0',
#             'paid_at': None,
#             'partner_carrier_id': '2ac26472-fce9-4ac0-8be7-02fe20ae5377',
#             'pay_term_id': 'a4704168-e929-4c89-b5d9-88776fadd3ab',
#             'qb_error_msg': '',
#             'qb_exported_at': None,
#             'qb_external_id': '',
#             'reference_number': 'BILL-906M0054',
#             'remit_to': {'address_1': '',
#                          'address_2': '',
#                          'city': '',
#                          'company_name': 'Greenfiber Wilkes-Barre',
#                          'contact_name': 'Teresa Eyler',
#                          'country': '',
#                          'postal': '',
#                          'state': ''},
#             'revision': 1,
#             'send_to_email': '',
#             'sent_at': None,
#             'status_id': 'saved',
#             'sub_total_amount': 1256.2,
#             'tax_amount': 0,
#             'total_amount': 1256.2},
#            {'bill_date': '2019-08-05',
#             'bill_to': {'address_1': '',
#                         'address_2': '',
#                         'city': '',
#                         'company_name': 'JEH',
#                         'contact_name': 'JEH',
#                         'country': '',
#                         'postal': '',
#                         'state': ''},
#             'cc_to_email': '',
#             'created_by': '014a9f9b-1772-461d-a54b-61788189f428',
#             'currency_id': 'usd',
#             'driver_id': None,
#             'due_date': '2019-09-04',
#             'external_id': '',
#             'full_id': 'BILL-906M0037',
#             'id': '90345a97-ae4a-4de5-84d6-36b63c93d639',
#             'is_tax_on': False,
#             'master_trip_id': '4be3d076-31ab-4ce3-a097-b18d3341cf1f',
#             'notes': '',
#             'org_id': 'd85bef54-5d5b-482f-81bb-35b1dd74e2c0',
#             'paid_at': None,
#             'partner_carrier_id': '2ac26472-fce9-4ac0-8be7-02fe20ae5377',
#             'pay_term_id': 'a4704168-e929-4c89-b5d9-88776fadd3ab',
#             'qb_error_msg': '',
#             'qb_exported_at': None,
#             'qb_external_id': '',
#             'reference_number': 'BILL-906M0037',
#             'remit_to': {'address_1': '',
#                          'address_2': '',
#                          'city': '',
#                          'company_name': 'Greenfiber Wilkes-Barre',
#                          'contact_name': 'Teresa Eyler',
#                          'country': '',
#                          'postal': '',
#                          'state': ''},
#             'revision': 1,
#             'send_to_email': '',
#             'sent_at': None,
#             'status_id': 'saved',
#             'sub_total_amount': 1520.2,
#             'tax_amount': 0,
#             'total_amount': 1520.2},
#            {'bill_date': '2019-08-05',
#             'bill_to': {'address_1': '',
#                         'address_2': '',
#                         'city': '',
#                         'company_name': 'JEH',
#                         'contact_name': 'JEH',
#                         'country': '',
#                         'postal': '',
#                         'state': ''},
#             'cc_to_email': '',
#             'created_by': '014a9f9b-1772-461d-a54b-61788189f428',
#             'currency_id': 'usd',
#             'driver_id': None,
#             'due_date': '2019-09-04',
#             'external_id': '',
#             'full_id': 'BILL-906M0044',
#             'id': 'fa2d8bfc-1eef-4a3c-b74e-0b7fc396bf97',
#             'is_tax_on': False,
#             'master_trip_id': 'e28d3ad4-786b-4b37-975a-485089b084e4',
#             'notes': '',
#             'org_id': 'd85bef54-5d5b-482f-81bb-35b1dd74e2c0',
#             'paid_at': None,
#             'partner_carrier_id': '2ac26472-fce9-4ac0-8be7-02fe20ae5377',
#             'pay_term_id': 'a4704168-e929-4c89-b5d9-88776fadd3ab',
#             'qb_error_msg': '',
#             'qb_exported_at': None,
#             'qb_external_id': '',
#             'reference_number': 'BILL-906M0044',
#             'remit_to': {'address_1': '',
#                          'address_2': '',
#                          'city': '',
#                          'company_name': 'Greenfiber Wilkes-Barre',
#                          'contact_name': 'Teresa Eyler',
#                          'country': '',
#                          'postal': '',
#                          'state': ''},
#             'revision': 1,
#             'send_to_email': '',
#             'sent_at': None,
#             'status_id': 'saved',
#             'sub_total_amount': 840.4,
#             'tax_amount': 0,
#             'total_amount': 840.4},
#            {'bill_date': '2019-08-05',
#             'bill_to': {'address_1': '',
#                         'address_2': '',
#                         'city': '',
#                         'company_name': 'JEH',
#                         'contact_name': 'JEH',
#                         'country': '',
#                         'postal': '',
#                         'state': ''},
#             'cc_to_email': '',
#             'created_by': '014a9f9b-1772-461d-a54b-61788189f428',
#             'currency_id': 'usd',
#             'driver_id': None,
#             'due_date': '2019-09-04',
#             'external_id': '',
#             'full_id': 'BILL-906M0021',
#             'id': '36dd6d0f-ba22-4942-90ed-380470d63dc2',
#             'is_tax_on': False,
#             'master_trip_id': '21de6a26-35a3-4363-9b30-031e5d7dfc9c',
#             'notes': '',
#             'org_id': 'd85bef54-5d5b-482f-81bb-35b1dd74e2c0',
#             'paid_at': None,
#             'partner_carrier_id': '2ac26472-fce9-4ac0-8be7-02fe20ae5377',
#             'pay_term_id': 'a4704168-e929-4c89-b5d9-88776fadd3ab',
#             'qb_error_msg': '',
#             'qb_exported_at': None,
#             'qb_external_id': '',
#             'reference_number': 'BILL-906M0021',
#             'remit_to': {'address_1': '',
#                          'address_2': '',
#                          'city': '',
#                          'company_name': 'Greenfiber Wilkes-Barre',
#                          'contact_name': 'Teresa Eyler',
#                          'country': '',
#                          'postal': '',
#                          'state': ''},
#             'revision': 1,
#             'send_to_email': '',
#             'sent_at': None,
#             'status_id': 'saved',
#             'sub_total_amount': 811.8,
#             'tax_amount': 0,
#             'total_amount': 811.8},
#            {'bill_date': '2019-08-05',
#             'bill_to': {'address_1': '',
#                         'address_2': '',
#                         'city': '',
#                         'company_name': 'JEH',
#                         'contact_name': 'JEH',
#                         'country': '',
#                         'postal': '',
#                         'state': ''},
#             'cc_to_email': '',
#             'created_by': '014a9f9b-1772-461d-a54b-61788189f428',
#             'currency_id': 'usd',
#             'driver_id': None,
#             'due_date': '2019-09-04',
#             'external_id': '',
#             'full_id': 'BILL-906M0002',
#             'id': '077de439-0a56-4f1d-ae73-5f241758c811',
#             'is_tax_on': False,
#             'master_trip_id': 'ec32cbe9-22fe-4cff-be3a-cb28dcfa8d94',
#             'notes': '',
#             'org_id': 'd85bef54-5d5b-482f-81bb-35b1dd74e2c0',
#             'paid_at': None,
#             'partner_carrier_id': '2ac26472-fce9-4ac0-8be7-02fe20ae5377',
#             'pay_term_id': 'a4704168-e929-4c89-b5d9-88776fadd3ab',
#             'qb_error_msg': '',
#             'qb_exported_at': None,
#             'qb_external_id': '',
#             'reference_number': 'BILL-906M0002',
#             'remit_to': {'address_1': '',
#                          'address_2': '',
#                          'city': '',
#                          'company_name': 'Greenfiber Wilkes-Barre',
#                          'contact_name': 'Teresa Eyler',
#                          'country': '',
#                          'postal': '',
#                          'state': ''},
#             'revision': 1,
#             'send_to_email': '',
#             'sent_at': None,
#             'status_id': 'saved',
#             'sub_total_amount': 1240.8,
#             'tax_amount': 0,
#             'total_amount': 1240.8},
#            {'bill_date': '2019-08-05',
#             'bill_to': {'address_1': '',
#                         'address_2': '',
#                         'city': '',
#                         'company_name': 'DON DEROSE',
#                         'contact_name': 'DON DEROSE',
#                         'country': '',
#                         'postal': '',
#                         'state': ''},
#             'cc_to_email': '',
#             'created_by': '014a9f9b-1772-461d-a54b-61788189f428',
#             'currency_id': 'usd',
#             'driver_id': None,
#             'due_date': '2019-09-04',
#             'external_id': '',
#             'full_id': 'BILL-906M0019',
#             'id': 'dcb95f06-ccf6-40ee-9dc5-27a626369bf9',
#             'is_tax_on': False,
#             'master_trip_id': '125b3146-dea2-4387-b116-a45b9679fa2c',
#             'notes': '',
#             'org_id': 'd85bef54-5d5b-482f-81bb-35b1dd74e2c0',
#             'paid_at': None,
#             'partner_carrier_id': 'b9745d32-d2fd-46c9-b195-c72775f281cd',
#             'pay_term_id': 'a4704168-e929-4c89-b5d9-88776fadd3ab',
#             'qb_error_msg': '',
#             'qb_exported_at': None,
#             'qb_external_id': '',
#             'reference_number': 'BILL-906M0019',
#             'remit_to': {'address_1': '',
#                          'address_2': '',
#                          'city': '',
#                          'company_name': 'Greenfiber Wilkes-Barre',
#                          'contact_name': 'Teresa Eyler',
#                          'country': '',
#                          'postal': '',
#                          'state': ''},
#             'revision': 1,
#             'send_to_email': '',
#             'sent_at': None,
#             'status_id': 'saved',
#             'sub_total_amount': 1696.1999999999998,
#             'tax_amount': 0,
#             'total_amount': 1696.2},
#            {'bill_date': '2019-08-05',
#             'bill_to': {'address_1': '',
#                         'address_2': '',
#                         'city': '',
#                         'company_name': 'DON DEROSE',
#                         'contact_name': 'DON DEROSE',
#                         'country': '',
#                         'postal': '',
#                         'state': ''},
#             'cc_to_email': '',
#             'created_by': '014a9f9b-1772-461d-a54b-61788189f428',
#             'currency_id': 'usd',
#             'driver_id': None,
#             'due_date': '2019-09-04',
#             'external_id': '',
#             'full_id': 'BILL-906M0004',
#             'id': '05656039-ad71-4a4e-88c0-71a3992745ca',
#             'is_tax_on': False,
#             'master_trip_id': 'ba94b6a9-e6b2-4578-afee-a31ff7b47b94',
#             'notes': '',
#             'org_id': 'd85bef54-5d5b-482f-81bb-35b1dd74e2c0',
#             'paid_at': None,
#             'partner_carrier_id': 'b9745d32-d2fd-46c9-b195-c72775f281cd',
#             'pay_term_id': 'a4704168-e929-4c89-b5d9-88776fadd3ab',
#             'qb_error_msg': '',
#             'qb_exported_at': None,
#             'qb_external_id': '',
#             'reference_number': 'BILL-906M0004',
#             'remit_to': {'address_1': '',
#                          'address_2': '',
#                          'city': '',
#                          'company_name': 'Greenfiber Wilkes-Barre',
#                          'contact_name': 'Teresa Eyler',
#                          'country': '',
#                          'postal': '',
#                          'state': ''},
#             'revision': 1,
#             'send_to_email': '',
#             'sent_at': None,
#             'status_id': 'saved',
#             'sub_total_amount': 1504.8,
#             'tax_amount': 0,
#             'total_amount': 1504.8},
#            {'bill_date': '2019-08-05',
#             'bill_to': {'address_1': '',
#                         'address_2': '',
#                         'city': '',
#                         'company_name': 'DALE',
#                         'contact_name': 'DALE',
#                         'country': '',
#                         'postal': '',
#                         'state': ''},
#             'cc_to_email': '',
#             'created_by': '014a9f9b-1772-461d-a54b-61788189f428',
#             'currency_id': 'usd',
#             'driver_id': None,
#             'due_date': '2019-09-04',
#             'external_id': '',
#             'full_id': 'BILL-906M0055',
#             'id': 'cfe8332d-b08e-4a91-bec3-79e9c75759a4',
#             'is_tax_on': False,
#             'master_trip_id': '18364429-51f1-419a-8943-22eb7293529d',
#             'notes': '',
#             'org_id': 'd85bef54-5d5b-482f-81bb-35b1dd74e2c0',
#             'paid_at': None,
#             'partner_carrier_id': '52ffd84f-dbe5-41e6-9f38-16e8820fc457',
#             'pay_term_id': 'a4704168-e929-4c89-b5d9-88776fadd3ab',
#             'qb_error_msg': '',
#             'qb_exported_at': None,
#             'qb_external_id': '',
#             'reference_number': 'BILL-906M0055',
#             'remit_to': {'address_1': '',
#                          'address_2': '',
#                          'city': '',
#                          'company_name': 'Greenfiber Wilkes-Barre',
#                          'contact_name': 'Teresa Eyler',
#                          'country': '',
#                          'postal': '',
#                          'state': ''},
#             'revision': 1,
#             'send_to_email': '',
#             'sent_at': None,
#             'status_id': 'saved',
#             'sub_total_amount': 917.4,
#             'tax_amount': 0,
#             'total_amount': 917.4},
#            {'bill_date': '2019-08-05',
#             'bill_to': {'address_1': '',
#                         'address_2': '',
#                         'city': '',
#                         'company_name': 'DALE',
#                         'contact_name': 'DALE',
#                         'country': '',
#                         'postal': '',
#                         'state': ''},
#             'cc_to_email': '',
#             'created_by': '014a9f9b-1772-461d-a54b-61788189f428',
#             'currency_id': 'usd',
#             'driver_id': None,
#             'due_date': '2019-09-04',
#             'external_id': '',
#             'full_id': 'BILL-906M0035',
#             'id': '8d162310-e814-4e54-b220-aa003378f381',
#             'is_tax_on': False,
#             'master_trip_id': '6e70c3cb-087e-429b-94ca-747826815f7e',
#             'notes': '',
#             'org_id': 'd85bef54-5d5b-482f-81bb-35b1dd74e2c0',
#             'paid_at': None,
#             'partner_carrier_id': '52ffd84f-dbe5-41e6-9f38-16e8820fc457',
#             'pay_term_id': 'a4704168-e929-4c89-b5d9-88776fadd3ab',
#             'qb_error_msg': '',
#             'qb_exported_at': None,
#             'qb_external_id': '',
#             'reference_number': 'BILL-906M0035',
#             'remit_to': {'address_1': '',
#                          'address_2': '',
#                          'city': '',
#                          'company_name': 'Greenfiber Wilkes-Barre',
#                          'contact_name': 'Teresa Eyler',
#                          'country': '',
#                          'postal': '',
#                          'state': ''},
#             'revision': 1,
#             'send_to_email': '',
#             'sent_at': None,
#             'status_id': 'saved',
#             'sub_total_amount': 1489.4,
#             'tax_amount': 0,
#             'total_amount': 1489.4},
#            {'bill_date': '2019-08-05',
#             'bill_to': {'address_1': '',
#                         'address_2': '',
#                         'city': '',
#                         'company_name': 'DALE',
#                         'contact_name': 'DALE',
#                         'country': '',
#                         'postal': '',
#                         'state': ''},
#             'cc_to_email': '',
#             'created_by': '014a9f9b-1772-461d-a54b-61788189f428',
#             'currency_id': 'usd',
#             'driver_id': None,
#             'due_date': '2019-09-04',
#             'external_id': '',
#             'full_id': 'BILL-906M0007',
#             'id': 'c3af79b8-b82b-4705-aa15-47add50f4a59',
#             'is_tax_on': False,
#             'master_trip_id': '1508ac9f-68e4-4fe1-8e57-e27f68f5aa06',
#             'notes': '',
#             'org_id': 'd85bef54-5d5b-482f-81bb-35b1dd74e2c0',
#             'paid_at': None,
#             'partner_carrier_id': '52ffd84f-dbe5-41e6-9f38-16e8820fc457',
#             'pay_term_id': 'a4704168-e929-4c89-b5d9-88776fadd3ab',
#             'qb_error_msg': '',
#             'qb_exported_at': None,
#             'qb_external_id': '',
#             'reference_number': 'BILL-906M0007',
#             'remit_to': {'address_1': '',
#                          'address_2': '',
#                          'city': '',
#                          'company_name': 'Greenfiber Wilkes-Barre',
#                          'contact_name': 'Teresa Eyler',
#                          'country': '',
#                          'postal': '',
#                          'state': ''},
#             'revision': 1,
#             'send_to_email': '',
#             'sent_at': None,
#             'status_id': 'saved',
#             'sub_total_amount': 1482.8,
#             'tax_amount': 0,
#             'total_amount': 1482.8},
#            {'bill_date': '2019-08-05',
#             'bill_to': {'address_1': '',
#                         'address_2': '',
#                         'city': '',
#                         'company_name': 'CJM',
#                         'contact_name': 'CJM',
#                         'country': '',
#                         'postal': '',
#                         'state': ''},
#             'cc_to_email': '',
#             'created_by': '014a9f9b-1772-461d-a54b-61788189f428',
#             'currency_id': 'usd',
#             'driver_id': None,
#             'due_date': '2019-09-04',
#             'external_id': '',
#             'full_id': 'BILL-906M0076',
#             'id': '8f553856-bedd-4aea-9476-4afcc07c9ace',
#             'is_tax_on': False,
#             'master_trip_id': '5d3dbbfd-8637-4752-8480-7f8fc3c9eef5',
#             'notes': '',
#             'org_id': 'd85bef54-5d5b-482f-81bb-35b1dd74e2c0',
#             'paid_at': None,
#             'partner_carrier_id': 'a042c6c6-b657-49fa-bc69-2531b3701b61',
#             'pay_term_id': 'a4704168-e929-4c89-b5d9-88776fadd3ab',
#             'qb_error_msg': '',
#             'qb_exported_at': None,
#             'qb_external_id': '',
#             'reference_number': 'BILL-906M0076',
#             'remit_to': {'address_1': '',
#                          'address_2': '',
#                          'city': '',
#                          'company_name': 'Greenfiber Wilkes-Barre',
#                          'contact_name': 'Teresa Eyler',
#                          'country': '',
#                          'postal': '',
#                          'state': ''},
#             'revision': 1,
#             'send_to_email': '',
#             'sent_at': None,
#             'status_id': 'saved',
#             'sub_total_amount': 1480.6,
#             'tax_amount': 0,
#             'total_amount': 1480.6},
#            {'bill_date': '2019-08-05',
#             'bill_to': {'address_1': '',
#                         'address_2': '',
#                         'city': '',
#                         'company_name': 'CJM',
#                         'contact_name': 'CJM',
#                         'country': '',
#                         'postal': '',
#                         'state': ''},
#             'cc_to_email': '',
#             'created_by': '014a9f9b-1772-461d-a54b-61788189f428',
#             'currency_id': 'usd',
#             'driver_id': None,
#             'due_date': '2019-09-04',
#             'external_id': '',
#             'full_id': 'BILL-906M0057',
#             'id': '55056d9a-b249-4324-9be6-5b301a0982ca',
#             'is_tax_on': False,
#             'master_trip_id': '3a46b293-0a10-412e-b2a5-ac1fbf7839ba',
#             'notes': '',
#             'org_id': 'd85bef54-5d5b-482f-81bb-35b1dd74e2c0',
#             'paid_at': None,
#             'partner_carrier_id': 'a042c6c6-b657-49fa-bc69-2531b3701b61',
#             'pay_term_id': 'a4704168-e929-4c89-b5d9-88776fadd3ab',
#             'qb_error_msg': '',
#             'qb_exported_at': None,
#             'qb_external_id': '',
#             'reference_number': 'BILL-906M0057',
#             'remit_to': {'address_1': '',
#                          'address_2': '',
#                          'city': '',
#                          'company_name': 'Greenfiber Wilkes-Barre',
#                          'contact_name': 'Teresa Eyler',
#                          'country': '',
#                          'postal': '',
#                          'state': ''},
#             'revision': 1,
#             'send_to_email': '',
#             'sent_at': None,
#             'status_id': 'saved',
#             'sub_total_amount': 2058,
#             'tax_amount': 0,
#             'total_amount': 2058},
#            {'bill_date': '2019-08-05',
#             'bill_to': {'address_1': '',
#                         'address_2': '',
#                         'city': '',
#                         'company_name': 'CJM',
#                         'contact_name': 'CJM',
#                         'country': '',
#                         'postal': '',
#                         'state': ''},
#             'cc_to_email': '',
#             'created_by': '014a9f9b-1772-461d-a54b-61788189f428',
#             'currency_id': 'usd',
#             'driver_id': None,
#             'due_date': '2019-09-04',
#             'external_id': '',
#             'full_id': 'BILL-906M0038',
#             'id': 'ab432060-d37d-4a97-9620-39d3143f7c85',
#             'is_tax_on': False,
#             'master_trip_id': '42c5a4c4-66c3-4060-8eee-0dbb4e2736c1',
#             'notes': '',
#             'org_id': 'd85bef54-5d5b-482f-81bb-35b1dd74e2c0',
#             'paid_at': None,
#             'partner_carrier_id': 'a042c6c6-b657-49fa-bc69-2531b3701b61',
#             'pay_term_id': 'a4704168-e929-4c89-b5d9-88776fadd3ab',
#             'qb_error_msg': '',
#             'qb_exported_at': None,
#             'qb_external_id': '',
#             'reference_number': 'BILL-906M0038',
#             'remit_to': {'address_1': '',
#                          'address_2': '',
#                          'city': '',
#                          'company_name': 'Greenfiber Wilkes-Barre',
#                          'contact_name': 'Teresa Eyler',
#                          'country': '',
#                          'postal': '',
#                          'state': ''},
#             'revision': 1,
#             'send_to_email': '',
#             'sent_at': None,
#             'status_id': 'saved',
#             'sub_total_amount': 1945,
#             'tax_amount': 0,
#             'total_amount': 1945},
#            {'bill_date': '2019-08-05',
#             'bill_to': {'address_1': '',
#                         'address_2': '',
#                         'city': '',
#                         'company_name': 'DALE',
#                         'contact_name': 'DALE',
#                         'country': '',
#                         'postal': '',
#                         'state': ''},
#             'cc_to_email': '',
#             'created_by': '014a9f9b-1772-461d-a54b-61788189f428',
#             'currency_id': 'usd',
#             'driver_id': None,
#             'due_date': '2019-09-04',
#             'external_id': '',
#             'full_id': 'BILL-906M0018',
#             'id': '35f27eb8-b227-466a-b01d-7b0c6b7587ee',
#             'is_tax_on': False,
#             'master_trip_id': '2113a214-4ca4-43ff-9b4a-947d52398a7d',
#             'notes': '',
#             'org_id': 'd85bef54-5d5b-482f-81bb-35b1dd74e2c0',
#             'paid_at': None,
#             'partner_carrier_id': '52ffd84f-dbe5-41e6-9f38-16e8820fc457',
#             'pay_term_id': 'a4704168-e929-4c89-b5d9-88776fadd3ab',
#             'qb_error_msg': '',
#             'qb_exported_at': None,
#             'qb_external_id': '',
#             'reference_number': 'BILL-906M0018',
#             'remit_to': {'address_1': '',
#                          'address_2': '',
#                          'city': '',
#                          'company_name': 'Greenfiber Wilkes-Barre',
#                          'contact_name': 'Teresa Eyler',
#                          'country': '',
#                          'postal': '',
#                          'state': ''},
#             'revision': 1,
#             'send_to_email': '',
#             'sent_at': None,
#             'status_id': 'saved',
#             'sub_total_amount': 1273.8,
#             'tax_amount': 0,
#             'total_amount': 1273.8},
#            {'bill_date': '2019-08-05',
#             'bill_to': {'address_1': '',
#                         'address_2': '',
#                         'city': '',
#                         'company_name': 'CJM',
#                         'contact_name': 'CJM',
#                         'country': '',
#                         'postal': '',
#                         'state': ''},
#             'cc_to_email': '',
#             'created_by': '014a9f9b-1772-461d-a54b-61788189f428',
#             'currency_id': 'usd',
#             'driver_id': None,
#             'due_date': '2019-09-04',
#             'external_id': '',
#             'full_id': 'BILL-906M0016',
#             'id': 'ba841c4b-aeb3-493f-9953-c254dd3f3247',
#             'is_tax_on': False,
#             'master_trip_id': '4cb58c57-752b-4732-bddc-653a7065d1dc',
#             'notes': '',
#             'org_id': 'd85bef54-5d5b-482f-81bb-35b1dd74e2c0',
#             'paid_at': None,
#             'partner_carrier_id': 'a042c6c6-b657-49fa-bc69-2531b3701b61',
#             'pay_term_id': 'a4704168-e929-4c89-b5d9-88776fadd3ab',
#             'qb_error_msg': '',
#             'qb_exported_at': None,
#             'qb_external_id': '',
#             'reference_number': 'BILL-906M0016',
#             'remit_to': {'address_1': '',
#                          'address_2': '',
#                          'city': '',
#                          'company_name': 'Greenfiber Wilkes-Barre',
#                          'contact_name': 'Teresa Eyler',
#                          'country': '',
#                          'postal': '',
#                          'state': ''},
#             'revision': 1,
#             'send_to_email': '',
#             'sent_at': None,
#             'status_id': 'saved',
#             'sub_total_amount': 1925,
#             'tax_amount': 0,
#             'total_amount': 1925},
#            {'bill_date': '2019-08-05',
#             'bill_to': {'address_1': '',
#                         'address_2': '',
#                         'city': '',
#                         'company_name': 'CJM',
#                         'contact_name': 'CJM',
#                         'country': '',
#                         'postal': '',
#                         'state': ''},
#             'cc_to_email': '',
#             'created_by': '014a9f9b-1772-461d-a54b-61788189f428',
#             'currency_id': 'usd',
#             'driver_id': None,
#             'due_date': '2019-09-04',
#             'external_id': '',
#             'full_id': 'BILL-906M0005',
#             'id': '3c48048b-7e73-4d2d-bfb1-0055c6f7cef4',
#             'is_tax_on': False,
#             'master_trip_id': '08091385-d464-4f51-9169-7d2637170b58',
#             'notes': '',
#             'org_id': 'd85bef54-5d5b-482f-81bb-35b1dd74e2c0',
#             'paid_at': None,
#             'partner_carrier_id': 'a042c6c6-b657-49fa-bc69-2531b3701b61',
#             'pay_term_id': 'a4704168-e929-4c89-b5d9-88776fadd3ab',
#             'qb_error_msg': '',
#             'qb_exported_at': None,
#             'qb_external_id': '',
#             'reference_number': 'BILL-906M0005',
#             'remit_to': {'address_1': '',
#                          'address_2': '',
#                          'city': '',
#                          'company_name': 'Greenfiber Wilkes-Barre',
#                          'contact_name': 'Teresa Eyler',
#                          'country': '',
#                          'postal': '',
#                          'state': ''},
#             'revision': 1,
#             'send_to_email': '',
#             'sent_at': None,
#             'status_id': 'saved',
#             'sub_total_amount': 1601.6,
#             'tax_amount': 0,
#             'total_amount': 1601.6},
#            {'bill_date': '2019-07-29',
#             'bill_to': {'address_1': '',
#                         'address_2': '',
#                         'city': '',
#                         'company_name': 'CJM',
#                         'contact_name': 'CJM',
#                         'country': '',
#                         'postal': '',
#                         'state': ''},
#             'cc_to_email': '',
#             'created_by': '014a9f9b-1772-461d-a54b-61788189f428',
#             'currency_id': 'usd',
#             'driver_id': None,
#             'due_date': '2019-08-28',
#             'external_id': '',
#             'full_id': 'BILL-906M0003',
#             'id': 'ecf0ef92-59b5-49e2-aec1-1d86115b7259',
#             'is_tax_on': False,
#             'master_trip_id': 'd91ea5f7-da9c-4669-97e3-b78d9d283c7d',
#             'notes': '',
#             'org_id': 'd85bef54-5d5b-482f-81bb-35b1dd74e2c0',
#             'paid_at': None,
#             'partner_carrier_id': 'a042c6c6-b657-49fa-bc69-2531b3701b61',
#             'pay_term_id': 'a4704168-e929-4c89-b5d9-88776fadd3ab',
#             'qb_error_msg': '',
#             'qb_exported_at': None,
#             'qb_external_id': '',
#             'reference_number': 'BILL-906M0003',
#             'remit_to': {'address_1': '',
#                          'address_2': '',
#                          'city': '',
#                          'company_name': 'Greenfiber Wilkes-Barre',
#                          'contact_name': 'Teresa Eyler',
#                          'country': '',
#                          'postal': '',
#                          'state': ''},
#             'revision': 1,
#             'send_to_email': '',
#             'sent_at': None,
#             'status_id': 'saved',
#             'sub_total_amount': 1383.46,
#             'tax_amount': 0,
#             'total_amount': 1383.46}],
#  'limit': 20,
#  'offset': 0,
#  'total': 18}

# %%
rr= RoseRocketIntegration('906')
auth = rr.authorg('906')
headers = {
            'Accept': 'application/json',
            'Authorization': 'Bearer {}'.format(auth)


        }

apiurl = 'https://platform.roserocket.com/api/v1/manifests/{}/legs'.format(
                    '0d5ccfee-94be-4e66-b7f4-acef07518038')
resp = requests.get(apiurl, headers=headers).json()
pp.pprint(resp)
# print(len(resp['legs']))
# Out:
# AUTHRESP: {'data': {'access_token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoiYTM3MDhkZDctNzhkOS00MzcxLThmODgtNTViMjYwYjcyMDBmIiwib3JnX2lkIjoiZDg1YmVmNTQtNWQ1Yi00ODJmLTgxYmItMzViMWRkNzRlMmMwIiwib3JnX3R5cGVfaWQiOiJjYXJyaWVyIiwidXNlcl9yb2xlIjoiYWRtaW4iLCJleHAiOjE1NjkwOTgyNTYsImlhdCI6MTU2OTAxMTg1Nn0.0UHhOKlYAJCYcPl4RoqMnxH-nO4TQxJO5iRXbwLgI1c', 'refresh_token': '250f10eb-42b9-4cce-a94a-bedc2042706f', 'expires_in': 86400, 'token_type': 'Bearer'}}
# {'legs': [{'accessorials': [],
#            'commodities': [{'commodity_type': 'package',
#                             'commodity_type_other': '',
#                             'description': '30 LB COCOON2 LOOSE FILL BORAT',
#                             'feet': 0,
#                             'freight_class': 'none',
#                             'height': 0,
#                             'id': '4c1dd259-bdc9-4713-8491-07c5b663b221',
#                             'is_stackable': False,
#                             'length': 0,
#                             'measurement_unit': 'inch',
#                             'name': '30 LB COCOON2 LOOSE FILL BORAT',
#                             'nmfc': 'none',
#                             'pieces': 1,
#                             'quantity': 528,
#                             'sku': 'INS765LD',
#                             'volume': 0,
#                             'weight': 30,
#                             'weight_unit': 'lb',
#                             'width': 0}],
#            'created_at': '2019-08-16T20:02:34.659535Z',
#            'delivery_notes': "OriginInstructions: ['', '', '', '']",
#            'destination': {'address_1': '21 RICE STREET',
#                            'address_2': '',
#                            'city': 'PRESQUE ISLE',
#                            'contact_name': '',
#                            'country': 'US',
#                            'email': '',
#                            'fax': '',
#                            'latitude': 46.6954104,
#                            'longitude': -68.0108228,
#                            'org_name': 'S.W. COLLINS',
#                            'phone': '(207) 764-2720',
#                            'phone_ext': '',
#                            'postal': '04769',
#                            'state': 'ME',
#                            'suite': '',
#                            'terminal_id': None},
#            'destination_appt_end_at': None,
#            'destination_appt_start_at': None,
#            'destination_end_at': None,
#            'destination_start_at': '2019-08-22T04:00:00Z',
#            'destination_stop_id': '5a795060-323a-4206-bcfc-18094cc8c207',
#            'external_id': '',
#            'history': {'destination_arrived_at': '2019-08-22T10:43:13Z',
#                        'destination_delivered_at': '2019-08-22T10:43:13Z',
#                        'destination_in_at': None,
#                        'destination_out_at': None,
#                        'origin_arrived_at': '2019-08-22T10:43:11Z',
#                        'origin_in_at': None,
#                        'origin_out_at': None,
#                        'origin_pickedup_at': '2019-08-22T10:43:11Z'},
#            'id': '5789d7ae-8921-41b6-90e8-a8bf73c450b7',
#            'manifest_id': '0d5ccfee-94be-4e66-b7f4-acef07518038',
#            'order_id': '3984974a-6530-4f32-94f8-73af0b2a8d57',
#            'org_id': 'd85bef54-5d5b-482f-81bb-35b1dd74e2c0',
#            'origin': {'address_1': '99 Passan Drive',
#                       'address_2': '',
#                       'city': 'Wilkes-Barre',
#                       'contact_name': '',
#                       'country': 'US',
#                       'email': '',
#                       'fax': '',
#                       'latitude': 41.29495,
#                       'longitude': -75.793575,
#                       'org_name': 'Greenfiber Wilkes-Barre',
#                       'phone': '',
#                       'phone_ext': '',
#                       'postal': '18702',
#                       'state': 'PA',
#                       'suite': '',
#                       'terminal_id': 'a3ca394a-44fa-47ff-be85-620d7fbb79c8'},
#            'origin_appt_end_at': None,
#            'origin_appt_start_at': None,
#            'origin_end_at': None,
#            'origin_start_at': '2019-08-16T04:00:00Z',
#            'origin_stop_id': '50bee13e-523b-4225-97cc-c6ac7f40ef08',
#            'pickup_notes': "OriginInstructions: ['', '', '', '']",
#            'public_id': '906-LBMADV-3-LEG-1.1',
#            'sequence_id': 1,
#            'status': 'unloaded',
#            'type': 'delivery',
#            'updated_at': '2019-08-22T10:43:14.994335Z',
#            'version': 1},
#           {'accessorials': [],
#            'commodities': [{'commodity_type': 'package',
#                             'commodity_type_other': '',
#                             'description': '30 LB COCOON2 LOOSE FILL BORAT',
#                             'feet': 0,
#                             'freight_class': 'none',
#                             'height': 0,
#                             'id': 'f2644c3c-6cc7-4c16-b61e-5a5c4d4b0015',
#                             'is_stackable': False,
#                             'length': 0,
#                             'measurement_unit': 'inch',
#                             'name': '30 LB COCOON2 LOOSE FILL BORAT',
#                             'nmfc': 'none',
#                             'pieces': 1,
#                             'quantity': 528,
#                             'sku': 'INS765LD',
#                             'volume': 0,
#                             'weight': 30,
#                             'weight_unit': 'lb',
#                             'width': 0}],
#            'created_at': '2019-08-16T20:02:33.927301Z',
#            'delivery_notes': "OriginInstructions: ['', '', '', '']",
#            'destination': {'address_1': '57 BANGOR STREET',
#                            'address_2': '(2',
#                            'city': 'HOULTON',
#                            'contact_name': '',
#                            'country': 'US',
#                            'email': '',
#                            'fax': '',
#                            'latitude': 46.1237897,
#                            'longitude': -67.845999,
#                            'org_name': 'S.W. COLLINS',
#                            'phone': '(207) 532-2263',
#                            'phone_ext': '',
#                            'postal': '04730',
#                            'state': 'ME',
#                            'suite': '',
#                            'terminal_id': None},
#            'destination_appt_end_at': None,
#            'destination_appt_start_at': None,
#            'destination_end_at': None,
#            'destination_start_at': '2019-08-22T04:00:00Z',
#            'destination_stop_id': 'e8289c98-99a4-4ae3-89e6-3265d2ec3fbb',
#            'external_id': '',
#            'history': {'destination_arrived_at': '2019-08-22T10:43:01Z',
#                        'destination_delivered_at': '2019-08-22T10:43:01Z',
#                        'destination_in_at': None,
#                        'destination_out_at': None,
#                        'origin_arrived_at': '2019-08-22T10:42:58Z',
#                        'origin_in_at': None,
#                        'origin_out_at': None,
#                        'origin_pickedup_at': '2019-08-22T10:42:58Z'},
#            'id': 'c509c3ac-3303-4dcd-9613-6fc2c36f5c43',
#            'manifest_id': '0d5ccfee-94be-4e66-b7f4-acef07518038',
#            'order_id': '0b2fa41b-4721-4a81-85c9-fc79826744c6',
#            'org_id': 'd85bef54-5d5b-482f-81bb-35b1dd74e2c0',
#            'origin': {'address_1': '99 Passan Drive',
#                       'address_2': '',
#                       'city': 'Wilkes-Barre',
#                       'contact_name': '',
#                       'country': 'US',
#                       'email': '',
#                       'fax': '',
#                       'latitude': 41.29495,
#                       'longitude': -75.793575,
#                       'org_name': 'Greenfiber Wilkes-Barre',
#                       'phone': '',
#                       'phone_ext': '',
#                       'postal': '18702',
#                       'state': 'PA',
#                       'suite': '',
#                       'terminal_id': 'a3ca394a-44fa-47ff-be85-620d7fbb79c8'},
#            'origin_appt_end_at': None,
#            'origin_appt_start_at': None,
#            'origin_end_at': None,
#            'origin_start_at': '2019-08-22T04:00:00Z',
#            'origin_stop_id': '50bee13e-523b-4225-97cc-c6ac7f40ef08',
#            'pickup_notes': "OriginInstructions: ['', '', '', '']",
#            'public_id': '906-LBMADV-2-LEG-1.1',
#            'sequence_id': 1,
#            'status': 'unloaded',
#            'type': 'delivery',
#            'updated_at': '2019-08-22T10:43:02.39277Z',
#            'version': 1}]}

# %%
TODO: 
    1. Make list to hold the first order_id from any manifest that has legcount >1
    2. If the current order id is in the multileg list, set the totalamount to zero, else set it to be the correct value
