# %%
from integration import RoseRocketIntegration, RoseRocketIntegrationBackend
from secretprod import secrets as pw
import requests
import xlwings as xw
import pprint
orgs = pw.orgs.keys()


db = RoseRocketIntegrationBackend()
pddata = []
pp = pprint.PrettyPrinter()
# pp.pprint(resp.json())

# %%
print("generating report...")
counter=0
for org in orgs:
    results = db.getOrderHistory(org)
    rr = RoseRocketIntegration(org)
    auth = rr.authorg(org)

    headers = {
        'Accept': 'application/json',
        'Authorization': 'Bearer {}'.format(auth)


    }
    apiurl='https://platform.sandbox01.roserocket.com/api/v1/bills'
    bills=requests.get(apiurl,headers=headers).json()
    
    
    for result in results:
        
       
        apiurl = 'https://platform.sandbox01.roserocket.com/api/v1/customers/ext:{}/orders/ext:{}'.format(
            result.ARDIVISIONNO+result.CUSTOMERNO, result.SALESORDERNO)

# %%
rr = RoseRocketIntegration('906')
auth=rr.authorg('906')
headers = {
        'Accept': 'application/json',
        'Authorization': 'Bearer {}'.format(auth)


    }
# params={"customer_id":"00LOWES"}

apiurl = 'https://platform.sandbox01.roserocket.com/api/v1/orders?limit=50&offset=50'
orders=requests.get(apiurl,headers=headers).json()

# print()
for i in range(0,int(1852/50)):
    apiurl = 'https://platform.sandbox01.roserocket.com/api/v1/orders?limit=50&offset={}'.format(i)
    orders=requests.get(apiurl,headers=headers).json()
    for order in orders['orders']:
        shortcode=order['customer']['short_code']
        print(shortcode)
        print(str(order['customer']['external_id']))
#         if(shortcode != str(order['customer']['external_id'])):
#             print("{} -- {} would have been marked cancelled! ".format(order['customer']['short_code'],order['id']))
        

# pp.pprint(orders['limit'])
# for order in orders['orders']:
#     pp.pprint(order['customer']['short_code'])
# Out:
# AUTHRESP: {'data': {'access_token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoiYTM3MDhkZDctNzhkOS00MzcxLThmODgtNTViMjYwYjcyMDBmIiwib3JnX2lkIjoiZDg1YmVmNTQtNWQ1Yi00ODJmLTgxYmItMzViMWRkNzRlMmMwIiwib3JnX3R5cGVfaWQiOiJjYXJyaWVyIiwidXNlcl9yb2xlIjoiYWRtaW4iLCJleHAiOjE1NzI3MjYyMzAsImlhdCI6MTU3MjYzOTgzMH0.Lxp7DUGQq2DNPIxrqJokjK3T0V7B1pYJKRrT8RNlIqM', 'refresh_token': '43fd539c-c3ee-442b-aa14-ae2c7b04f57c', 'expires_in': 86400, 'token_type': 'Bearer'}}
# HOMERD
#
# HOMERD
#
# AGSOC
#
# LUMBME
#
# HOMEDC
#
# HOMEDC
#
# HOMEDC
#
# HOMEDC
#
# HOMEDC
#
# AGSOC
#
# AGSOC
#
# AGSOC
#
# AGSOC
#
# EXLJM
#
# GALEDA
#
# GALEDA
#
# GALEDA
#
# GALEDA
#
# GALEDA
#
# INDIIN
#
# INDIIN
#
# INDIIN
#
# 84LUMB
#
# PESTCO
#
# INSTAL
#
# INDIIN
#
# INDIIN
#
# INSTAL
#
# INDIIN
#
# MARJAL
#
# INDIIN
#
# NORTEA
#
# INSTAL
#
# INDIIN
#
# GENERI
#
# GALEDA
#
# CDNFIB
#
# AFALON
#
# AFABOL
#
# PESTCO
#
# RMMZH
#
# FZQDT
#
# IGJHV
#
# FZQDT
#
# SSSOW
#
# FZQDT
#
# NWRDP
#
# NWRDP
#
# NWRDP
#
# NWRDP
#
# ...
